# %% [markdown]
# ## Results

# %%
# %matplotlib inline
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pyspark.sql.functions as sf

plt.style.use('bmh')
pd.options.display.max_columns = 500

# %%
features = ['broadcaster', 'credits', 'description_tfidf', 'genres', 'title_tfidf', 'sub_tfidf']

def combinations(features):
    combi = []
    for i in range(1, len(features)+1):
        combi = combi + list(itertools.combinations(features,i))
    return combi

combi = combinations(features)
combi.insert(0, None)
print(len(combi))
# Out:
# 64

# %%
combi[48]
# Out:
# ('broadcaster', 'description_tfidf', 'genres', 'title_tfidf')

# %% [markdown]
# ## V3

# %%
parts = ['0-18(2)-', '18-40(2)-', '40-58(2)-', '58-64(2)-'] 

paths = []
for i in range(0, len(parts)):
    paths.append('gs://dataproc-jupyter-eileen.npo-data.nl/data/results/marchv3results' + parts[i])
results_df = spark.read.parquet(*paths)

df = results_df.toPandas()
df['combination'] = df['combi']
df.sort_values('combi')
# Out:
#      epoch   test_p5    p5_std  test_p52   p5_std2  test_r-rank  rank_std  \
# 319  100.0  0.125987  0.118797  0.093548  0.102973     0.367549  0.345053
# 317   80.0  0.123449  0.118242  0.087097  0.102365     0.357388  0.340009
# 316   70.0  0.121541  0.118073  0.091935  0.102860     0.350971  0.337309
# 315   60.0  0.119787  0.118151  0.090323  0.102721     0.344512  0.334003
# 314   50.0  0.117043  0.117708  0.087097  0.099164     0.335407  0.329289
# 318   90.0  0.124728  0.118471  0.090323  0.102721     0.363077  0.343367
# 312   30.0  0.110136  0.116678  0.082258  0.098414     0.305771  0.309908
# 311   20.0  0.104912  0.115633  0.077419  0.097417     0.286896  0.296540
# 310   10.0  0.096206  0.113375  0.080645  0.098109     0.254884  0.273036
# 313   40.0  0.113901  0.117203  0.085484  0.098941     0.324030  0.322602
# 328   90.0  0.121849  0.118646  0.101613  0.099987     0.347274  0.332679
# 320   10.0  0.089286  0.110306  0.091935  0.099674     0.238553  0.263316
# 321   20.0  0.097626  0.113413  0.091935  0.099674     0.265446  0.283424
# 323   40.0  0.108459  0.116359  0.093548  0.099792     0.302742  0.309507
# 324   50.0  0.111922  0.117114  0.093548  0.099792     0.315996  0.317133
# 325   60.0  0.115193  0.117961  0.093548  0.099792     0.327787  0.324214
# 326   70.0  0.117692  0.118309  0.096774  0.099948     0.334893  0.327779
# 327   80.0  0.120191  0.118582  0.101613  0.103163     0.342382  0.331058
# 329  100.0  0.123301  0.118911  0.101613  0.103163     0.350450  0.333507
# 322   30.0  0.103171  0.114958  0.095161  0.099883     0.283030  0.294442
# 330   10.0  0.074765  0.106137  0.059677  0.091510     0.201511  0.249221
# 331   20.0  0.084698  0.111506  0.067742  0.094654     0.227870  0.262683
# 332   30.0  0.092454  0.114080  0.074194  0.096613     0.244368  0.269761
# 333   40.0  0.097729  0.115002  0.080645  0.101344     0.257047  0.274720
# 334   50.0  0.101834  0.115545  0.080645  0.101344     0.271322  0.284529
# 335   60.0  0.104167  0.115807  0.080645  0.101344     0.278607  0.289169
# 336   70.0  0.106364  0.115973  0.080645  0.101344     0.286687  0.293962
# 337   80.0  0.107958  0.116461  0.080645  0.101344     0.296015  0.302531
# 338   90.0  0.109198  0.116623  0.079032  0.097777     0.300823  0.305144
# 331      0.183083   0.217811      2
# 332      0.188088   0.221107      2
# 333      0.186375   0.217221      2
# 334      0.203053   0.238976      2
# 335      0.198486   0.226743      2
# 336      0.203009   0.236668      2
# 337      0.199432   0.223628      2
# 338      0.206988   0.234206      2
# 339      0.212337   0.244391      2
# ..            ...        ...    ...
# 406      0.237908   0.252505     61
# 409      0.244396   0.260067     61
# 408      0.243667   0.259423     61
# 407      0.230755   0.241725     61
# 401      0.206139   0.223672     61
# 404      0.217610   0.240634     61
# 403      0.213228   0.234323     61
# 402      0.218951   0.248355     61
# 400      0.193455   0.227786     61
# 405      0.234915   0.255716     61
# 411      0.176815   0.238515     62
# 410      0.182863   0.253776     62
# 412      0.166085   0.215807     62
# 419      0.206187   0.248089     62
# 414      0.170550   0.201167     62
# 415      0.177802   0.205243     62
# 416      0.185287   0.217521     62
# 417      0.193116   0.227300     62
# 418      0.207091   0.250936     62
# 413      0.169454   0.211401     62
# 420      0.125442   0.186473     63
# 421      0.138262   0.208212     63
# 423      0.144240   0.204966     63
# 424      0.164723   0.225970     63
# 425      0.160973   0.212699     63
# 426      0.171836   0.216155     63
# 427      0.182113   0.218276     63
# 428      0.185711   0.228172     63
# 429      0.188840   0.229487     63
# 422      0.131935   0.188658     63
#
#                                               features  combination
# 319                                               None            0
# 317                                               None            0
# 316                                               None            0
# 315                                               None            0
# 314                                               None            0
# 318                                               None            0
# 312                                               None            0
# 311                                               None            0
# 310                                               None            0
# 313                                               None            0
# 328                                   ('broadcaster',)            1
# 320                                   ('broadcaster',)            1
# 321                                   ('broadcaster',)            1
# 323                                   ('broadcaster',)            1
# 324                                   ('broadcaster',)            1
# 325                                   ('broadcaster',)            1
# 326                                   ('broadcaster',)            1
# 327                                   ('broadcaster',)            1
# 329                                   ('broadcaster',)            1
# 322                                   ('broadcaster',)            1
# 330                                       ('credits',)            2
# 331                                       ('credits',)            2
# 332                                       ('credits',)            2
# 333                                       ('credits',)            2
# 334                                       ('credits',)            2
# 335                                       ('credits',)            2
# 336                                       ('credits',)            2
# 337                                       ('credits',)            2
# 338                                       ('credits',)            2
# 339                                       ('credits',)            2
# ..                                                 ...          ...
# 406  ('broadcaster', 'description_tfidf', 'genres',...           61
# 409  ('broadcaster', 'description_tfidf', 'genres',...           61
# 408  ('broadcaster', 'description_tfidf', 'genres',...           61
# 407  ('broadcaster', 'description_tfidf', 'genres',...           61
# 401  ('broadcaster', 'description_tfidf', 'genres',...           61
# 404  ('broadcaster', 'description_tfidf', 'genres',...           61
# 403  ('broadcaster', 'description_tfidf', 'genres',...           61
# 402  ('broadcaster', 'description_tfidf', 'genres',...           61
# 400  ('broadcaster', 'description_tfidf', 'genres',...           61
# 405  ('broadcaster', 'description_tfidf', 'genres',...           61
# 411  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 410  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 412  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 419  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 414  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 415  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 416  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 417  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 418  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 413  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 420  ('broadcaster', 'credits', 'description_tfidf'...           63
# 421  ('broadcaster', 'credits', 'description_tfidf'...           63
# 423  ('broadcaster', 'credits', 'description_tfidf'...           63
# 424  ('broadcaster', 'credits', 'description_tfidf'...           63
# 425  ('broadcaster', 'credits', 'description_tfidf'...           63
# 426  ('broadcaster', 'credits', 'description_tfidf'...           63
# 427  ('broadcaster', 'credits', 'description_tfidf'...           63
# 428  ('broadcaster', 'credits', 'description_tfidf'...           63
# 429  ('broadcaster', 'credits', 'description_tfidf'...           63
# 422  ('broadcaster', 'credits', 'description_tfidf'...           63
#
# [640 rows x 12 columns]

# %%
f, axes = plt.subplots(1, 1, figsize=(7,8))
ax = sns.lineplot(x="epoch", y="test_p5",data=df, hue='combination', ax=axes)
#axes.set_title("Mean precision@5 for all content feature combinations")
axes.set(ylabel='mean p@5')
plt.show()

# %%
f, axes = plt.subplots(1, 1, figsize=(7,8))
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df, hue='combination', ax=axes)
axes.set(ylabel='mean p@5')
plt.show()

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))
ax = sns.lineplot(x="epoch", y="test_p5",data=df, hue='combination', ax=axes[0])
axes[0].set_title("Mean precision@5 for all content feature combinations")
axes[0].set(ylabel='mean p@5')
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df, hue='combination', ax=axes[1])
axes[1].set_title("Mean reciprocal rank for all content feature combinations")
axes[1].set(ylabel='mrr')
plt.show()

# %%
f, axes = plt.subplots(1, 1, figsize=(7,8))
ax = sns.lineplot(x="epoch", y="test_p52",data=df, hue='combination', ax=axes)
axes.set(ylabel='mean p@5')
plt.show()

# %%
f, axes = plt.subplots(1, 1, figsize=(7,8))
ax = sns.lineplot(x="epoch", y="test_r-rank2",data=df, hue='combination', ax=axes)
axes.set(ylabel='mean p@5')
plt.show()

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))
ax = sns.lineplot(x="epoch", y="test_p52",data=df, hue='combination', ax=axes[0])
axes[0].set_title("Mean precision@5 for all content feature combinations")
axes[0].set(ylabel='mean p@5')
ax = sns.lineplot(x="epoch", y="test_r-rank2",data=df, hue='combination', ax=axes[1])
axes[1].set_title("Mean reciprocal rank for all content feature combinations")
axes[1].set(ylabel='mrr')
plt.show()

# %% [markdown]
# ### precision

# %%
# highest mean p@k
p5 = df.groupby(['combination'])['test_p5'].transform(max) == df['test_p5']
df_p5 = df[p5].copy()
df_p5.sort_values('test_p5', ascending=False)
df_p5.loc[df_p5['test_p5'].idxmax()]
# Out:
# epoch                                                100
# test_p5                                         0.126077
# p5_std                                          0.118918
# test_p52                                       0.0951613
# p5_std2                                        0.0998829
# test_r-rank                                     0.365413
# rank_std                                        0.343312
# test_r-rank2                                    0.294563
# rank_std2                                        0.31661
# combi                                                 29
# features        ('broadcaster', 'genres', 'title_tfidf')
# combination                                           29
# Name: 9, dtype: object

# %%
df_p5.sort_values('test_p5', ascending=False)
# Out:
#      epoch   test_p5    p5_std  test_p52   p5_std2  test_r-rank  rank_std  \
# 9    100.0  0.126077  0.118918  0.095161  0.099883     0.365413  0.343312
# 319  100.0  0.125987  0.118797  0.093548  0.102973     0.367549  0.345053
# 519  100.0  0.125775  0.118789  0.111290  0.102556     0.367717  0.345132
# 99   100.0  0.125325  0.118983  0.093548  0.102973     0.360740  0.340821
# 399  100.0  0.125222  0.118605  0.101613  0.106244     0.356440  0.336165
# 299  100.0  0.125216  0.118509  0.091935  0.105949     0.365648  0.343280
# 129  100.0  0.125145  0.118372  0.091935  0.099674     0.363304  0.342756
# 199  100.0  0.125010  0.118823  0.093548  0.099792     0.365128  0.345006
# 309  100.0  0.124760  0.118551  0.088710  0.099361     0.358960  0.339669
# 349  100.0  0.124439  0.118531  0.085484  0.102149     0.359025  0.339754
# 239  100.0  0.124220  0.119213  0.088710  0.102556     0.356839  0.338604
# 249  100.0  0.124194  0.118635  0.091935  0.099674     0.356790  0.339227
# 19   100.0  0.124072  0.118692  0.093548  0.099792     0.354195  0.336805
# 229  100.0  0.123822  0.118526  0.101613  0.099987     0.360053  0.341333
# 209  100.0  0.123738  0.118185  0.090323  0.105814     0.361311  0.342610
# 29   100.0  0.123713  0.119121  0.091935  0.102860     0.355232  0.337260
# 139  100.0  0.123610  0.118612  0.091935  0.099674     0.354397  0.337106
# 369  100.0  0.123578  0.118835  0.101613  0.103163     0.354384  0.337488
# 429  100.0  0.076287  0.105882  0.066129  0.094089     0.199048  0.229174
#
#      test_r-rank2  rank_std2  combi  \
# 9        0.294563   0.316610     29
# 319      0.284095   0.310698      0
# 519      0.314320   0.318018     48
# 99       0.268696   0.279982     38
# 399      0.290091   0.292792      8
# 299      0.289701   0.303026     16
# 129      0.271514   0.298715     19
# 199      0.280995   0.304990     26
# 309      0.270385   0.284077     17
# 349      0.255533   0.278835      3
# 239      0.268021   0.290912     10
# 249      0.245403   0.248146     11
# 19       0.259562   0.271980     30
# 229      0.301597   0.318552      9
# 209      0.243451   0.240614     27
# 29       0.255788   0.263899     31
# 139      0.292591   0.315770     20
# 369      0.276144   0.294302      5
# 379      0.266346   0.268868      6
# 579      0.302477   0.319812     51
# 329      0.299571   0.309275      1
# 119      0.280232   0.306023     18
# 359      0.285969   0.320057      4
# 149      0.252320   0.277543     21
# 599      0.279479   0.294297     41
# 559      0.289150   0.315014     49
# 219      0.268915   0.281780     28
# 569      0.290367   0.308676     50
# 269      0.256190   0.269119     13
# 409      0.244396   0.260067     61
# ..            ...        ...    ...
# 589      0.275160   0.308682     40
# 279      0.227711   0.235723     14
# 169      0.240468   0.268163     23
# 529      0.278065   0.299225     43
# 69       0.238604   0.266219     35
# 159      0.244514   0.268065     22
# 339      0.212337   0.244391      2
# 489      0.262201   0.280098     57
# 499      0.228005   0.262602     46
# 39       0.244055   0.266925     32
# 549      0.218148   0.249636     45
# 609      0.236511   0.262794     42
# 619      0.234254   0.255726     52
# 469      0.243878   0.270198     55
# 89       0.254101   0.294645     37
# 189      0.248119   0.274404     25
# 459      0.237038   0.257540     60
# 259      0.236829   0.263316     12
# 49       0.248811   0.276540     33
# 79       0.234103   0.264230     36
# 289      0.237405   0.252041     15
# 639      0.222831   0.259772     54
# 419      0.206187   0.248089     62
# 629      0.206709   0.240063     53
# 439      0.226440   0.271172     58
# 59       0.233136   0.257458     34
# 509      0.235482   0.269487     47
# 539      0.237128   0.272721     44
# 449      0.211601   0.243461     59
# 429      0.188840   0.229487     63
#
#                                               features  combination
# 9             ('broadcaster', 'genres', 'title_tfidf')           29
# 319                                               None            0
# 519  ('broadcaster', 'description_tfidf', 'genres',...           48
# 99      ('description_tfidf', 'genres', 'title_tfidf')           38
# 399               ('broadcaster', 'description_tfidf')            8
# 299                    ('description_tfidf', 'genres')           16
# 129                          ('genres', 'title_tfidf')           19
# 199     ('broadcaster', 'description_tfidf', 'genres')           26
# 309               ('description_tfidf', 'title_tfidf')           17
# 349                             ('description_tfidf',)            3
# 239                     ('broadcaster', 'title_tfidf')           10
# 249                       ('broadcaster', 'sub_tfidf')           11
# 19              ('broadcaster', 'genres', 'sub_tfidf')           30
# 229                          ('broadcaster', 'genres')            9
# 209  ('broadcaster', 'description_tfidf', 'title_tf...           27
# 29         ('broadcaster', 'title_tfidf', 'sub_tfidf')           31
# 139                            ('genres', 'sub_tfidf')           20
# 369                                   ('title_tfidf',)            5
# 379                                     ('sub_tfidf',)            6
# 579  ('broadcaster', 'genres', 'title_tfidf', 'sub_...           51
# 329                                   ('broadcaster',)            1
# 119                 ('description_tfidf', 'sub_tfidf')           18
# 359                                        ('genres',)            4
# 149                       ('title_tfidf', 'sub_tfidf')           21
# 599             ('genres', 'title_tfidf', 'sub_tfidf')           41
# 559  ('broadcaster', 'description_tfidf', 'genres',...           49
# 219  ('broadcaster', 'description_tfidf', 'sub_tfidf')           28
# 569  ('broadcaster', 'description_tfidf', 'title_tf...           50
# 269                              ('credits', 'genres')           13
# 409  ('broadcaster', 'description_tfidf', 'genres',...           61
# ..                                                 ...          ...
# 589  ('description_tfidf', 'title_tfidf', 'sub_tfidf')           40
# 279                         ('credits', 'title_tfidf')           14
# 169               ('broadcaster', 'credits', 'genres')           23
# 529  ('broadcaster', 'credits', 'description_tfidf'...           43
# 69                ('credits', 'genres', 'title_tfidf')           35
# 159    ('broadcaster', 'credits', 'description_tfidf')           22
# 339                                       ('credits',)            2
# 489  ('broadcaster', 'credits', 'description_tfidf'...           57
# 499  ('broadcaster', 'credits', 'genres', 'sub_tfidf')           46
# 39          ('credits', 'description_tfidf', 'genres')           32
# 549  ('broadcaster', 'credits', 'genres', 'title_tf...           45
# 609  ('broadcaster', 'credits', 'description_tfidf'...           42
# 619  ('credits', 'description_tfidf', 'genres', 'ti...           52
# 469  ('credits', 'genres', 'title_tfidf', 'sub_tfidf')           55
# 89             ('credits', 'title_tfidf', 'sub_tfidf')           37
# 189            ('broadcaster', 'credits', 'sub_tfidf')           25
# 459  ('broadcaster', 'credits', 'genres', 'title_tf...           60
# 259                   ('credits', 'description_tfidf')           12
# 49     ('credits', 'description_tfidf', 'title_tfidf')           33
# 79                  ('credits', 'genres', 'sub_tfidf')           36
# 289                           ('credits', 'sub_tfidf')           15
# 639  ('credits', 'description_tfidf', 'title_tfidf'...           54
# 419  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 629  ('credits', 'description_tfidf', 'genres', 'su...           53
# 439  ('broadcaster', 'credits', 'description_tfidf'...           58
# 59       ('credits', 'description_tfidf', 'sub_tfidf')           34
# 509  ('broadcaster', 'credits', 'title_tfidf', 'sub...           47
# 539  ('broadcaster', 'credits', 'description_tfidf'...           44
# 449  ('broadcaster', 'credits', 'description_tfidf'...           59
# 429  ('broadcaster', 'credits', 'description_tfidf'...           63
#
# [64 rows x 12 columns]

# %%
high_base = [0, 29]
df_50 = df[df['combination'].isin(high_base)].copy()
f, axes = plt.subplots(1, 2, figsize=(16,3))
ax = sns.lineplot(x="epoch", y="test_p5",data=df_50, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[0])
axes[0].set_title("Mean precision@5 for baseline and top combination")
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df_50, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[1])
axes[1].set_title("Mean reciprocal rank for baseline and top combination")
plt.show()

# %%
# highest mean p@k
p52 = df.groupby(['combination'])['test_p52'].transform(max) == df['test_p52']
df_p52 = df[p52].copy()
df_p52.sort_values('test_p52', ascending=False)
df_p52.loc[df_p52['test_p52'].idxmax()]
# Out:
# epoch                                                         100
# test_p5                                                  0.125775
# p5_std                                                   0.118789
# test_p52                                                  0.11129
# p5_std2                                                  0.102556
# test_r-rank                                              0.367717
# rank_std                                                 0.345132
# test_r-rank2                                              0.31432
# rank_std2                                                0.318018
# combi                                                          48
# features        ('broadcaster', 'description_tfidf', 'genres',...
# combination                                                    48
# Name: 519, dtype: object

# %%
df_p52.sort_values('test_p52', ascending=False)
# Out:
#      epoch   test_p5    p5_std  test_p52   p5_std2  test_r-rank  rank_std  \
#
# 627      0.199688   0.239303     53
# 439      0.226440   0.271172     58
# 433      0.208277   0.258914     58
# 417      0.193116   0.227300     62
# 447      0.218524   0.265875     59
# 449      0.211601   0.243461     59
# 427      0.182113   0.218276     63
#
#                                               features  combination
# 519  ('broadcaster', 'description_tfidf', 'genres',...           48
# 397               ('broadcaster', 'description_tfidf')            8
# 229                          ('broadcaster', 'genres')            9
# 327                                   ('broadcaster',)            1
# 369                                   ('title_tfidf',)            5
# 568  ('broadcaster', 'description_tfidf', 'title_tf...           50
# 329                                   ('broadcaster',)            1
# 328                                   ('broadcaster',)            1
# 557  ('broadcaster', 'description_tfidf', 'genres',...           49
# 119                 ('description_tfidf', 'sub_tfidf')           18
# 296                    ('description_tfidf', 'genres')           16
# 8             ('broadcaster', 'genres', 'title_tfidf')           29
# 476  ('description_tfidf', 'genres', 'title_tfidf',...           56
# 478  ('description_tfidf', 'genres', 'title_tfidf',...           56
# 127                          ('genres', 'title_tfidf')           19
# 489  ('broadcaster', 'credits', 'description_tfidf'...           57
# 17              ('broadcaster', 'genres', 'sub_tfidf')           30
# 97      ('description_tfidf', 'genres', 'title_tfidf')           38
# 378                                     ('sub_tfidf',)            6
# 379                                     ('sub_tfidf',)            6
# 376                                     ('sub_tfidf',)            6
# 138                            ('genres', 'sub_tfidf')           20
# 579  ('broadcaster', 'genres', 'title_tfidf', 'sub_...           51
# 108       ('description_tfidf', 'genres', 'sub_tfidf')           39
# 527  ('broadcaster', 'credits', 'description_tfidf'...           43
# 147                       ('title_tfidf', 'sub_tfidf')           21
# 217  ('broadcaster', 'description_tfidf', 'sub_tfidf')           28
# 218  ('broadcaster', 'description_tfidf', 'sub_tfidf')           28
# 594             ('genres', 'title_tfidf', 'sub_tfidf')           41
# 28         ('broadcaster', 'title_tfidf', 'sub_tfidf')           31
# ..                                                 ...          ...
# 258                   ('credits', 'description_tfidf')           12
# 74                  ('credits', 'genres', 'sub_tfidf')           36
# 178          ('broadcaster', 'credits', 'title_tfidf')           24
# 177          ('broadcaster', 'credits', 'title_tfidf')           24
# 159    ('broadcaster', 'credits', 'description_tfidf')           22
# 69                ('credits', 'genres', 'title_tfidf')           35
# 276                         ('credits', 'title_tfidf')           14
# 165               ('broadcaster', 'credits', 'genres')           23
# 59       ('credits', 'description_tfidf', 'sub_tfidf')           34
# 58       ('credits', 'description_tfidf', 'sub_tfidf')           34
# 508  ('broadcaster', 'credits', 'title_tfidf', 'sub...           47
# 498  ('broadcaster', 'credits', 'genres', 'sub_tfidf')           46
# 639  ('credits', 'description_tfidf', 'title_tfidf'...           54
# 497  ('broadcaster', 'credits', 'genres', 'sub_tfidf')           46
# 496  ('broadcaster', 'credits', 'genres', 'sub_tfidf')           46
# 339                                       ('credits',)            2
# 618  ('credits', 'description_tfidf', 'genres', 'ti...           52
# 619  ('credits', 'description_tfidf', 'genres', 'ti...           52
# 608  ('broadcaster', 'credits', 'description_tfidf'...           42
# 609  ('broadcaster', 'credits', 'description_tfidf'...           42
# 83             ('credits', 'title_tfidf', 'sub_tfidf')           37
# 549  ('broadcaster', 'credits', 'genres', 'title_tf...           45
# 539  ('broadcaster', 'credits', 'description_tfidf'...           44
# 627  ('credits', 'description_tfidf', 'genres', 'su...           53
# 439  ('broadcaster', 'credits', 'description_tfidf'...           58
# 433  ('broadcaster', 'credits', 'description_tfidf'...           58
# 417  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 447  ('broadcaster', 'credits', 'description_tfidf'...           59
# 449  ('broadcaster', 'credits', 'description_tfidf'...           59
# 427  ('broadcaster', 'credits', 'description_tfidf'...           63
#
# [80 rows x 12 columns]

# %%
high_base = [0, 48]
df_54 = df[df['combination'].isin(high_base)].copy()
f, axes = plt.subplots(1, 2, figsize=(16,3))
ax = sns.lineplot(x="epoch", y="test_p52",data=df_54, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[0])
axes[0].set_title("Mean precision@5 for baseline and top combination")
ax = sns.lineplot(x="epoch", y="test_r-rank2",data=df_54, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[1])
axes[1].set_title("Mean reciprocal rank for baseline and top combination")
plt.show()

# %%
high_base1 = [0, 29]
df_precision1 = df[df['combination'].isin(high_base1)].copy()
high_base2 = [0, 48]
df_precision2 = df[df['combination'].isin(high_base2)].copy()

f, axes = plt.subplots(1, 2, figsize=(15,3))
ax = sns.lineplot(x="epoch", y="test_p5",data=df_precision1, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[0])
axes[0].set_title("Mean precision@5 of the Baseline and Top Combination on the Test Set", fontsize=11)
axes[0].set(ylabel='mean p@5')
ax = sns.lineplot(x="epoch", y="test_p52",data=df_precision2, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[1])
axes[1].set_title("Mean precision@5 of the Baseline and Top Combination on the Recommended Test Set", fontsize = 11)
axes[1].set(ylabel='mean p@5')
plt.show()

# %% [markdown]
# ### rank

# %%
# highest mean reciprocal rank
rr5 = df.groupby(['combination'])['test_r-rank'].transform(max) == df['test_r-rank']
df_rr5 = df[rr5].copy()
df_rr5.sort_values('test_r-rank', ascending=False)
df_rr5.loc[df_rr5['test_r-rank'].idxmax()]
# Out:
# epoch                                                         100
# test_p5                                                  0.125775
# p5_std                                                   0.118789
# test_p52                                                  0.11129
# p5_std2                                                  0.102556
# test_r-rank                                              0.367717
# rank_std                                                 0.345132
# test_r-rank2                                              0.31432
# rank_std2                                                0.318018
# combi                                                          48
# features        ('broadcaster', 'description_tfidf', 'genres',...
# combination                                                    48
# Name: 519, dtype: object

# %%
df_rr5.sort_values('test_r-rank', ascending=False)
# Out:
#      epoch   test_p5    p5_std  test_p52   p5_std2  test_r-rank  rank_std  \
# 519  100.0  0.125775  0.118789  0.111290  0.102556     0.367717  0.345132
# 319  100.0  0.125987  0.118797  0.093548  0.102973     0.367549  0.345053
# 299  100.0  0.125216  0.118509  0.091935  0.105949     0.365648  0.343280
# 9    100.0  0.126077  0.118918  0.095161  0.099883     0.365413  0.343312
# 199  100.0  0.125010  0.118823  0.093548  0.099792     0.365128  0.345006
# 129  100.0  0.125145  0.118372  0.091935  0.099674     0.363304  0.342756
# 209  100.0  0.123738  0.118185  0.090323  0.105814     0.361311  0.342610
# 99   100.0  0.125325  0.118983  0.093548  0.102973     0.360740  0.340821
# 229  100.0  0.123822  0.118526  0.101613  0.099987     0.360053  0.341333
# 349  100.0  0.124439  0.118531  0.085484  0.102149     0.359025  0.339754
# 309  100.0  0.124760  0.118551  0.088710  0.099361     0.358960  0.339669
# 379  100.0  0.123456  0.118870  0.095161  0.099883     0.358376  0.340894
# 239  100.0  0.124220  0.119213  0.088710  0.102556     0.356839  0.338604
# 249  100.0  0.124194  0.118635  0.091935  0.099674     0.356790  0.339227
# 399  100.0  0.125222  0.118605  0.101613  0.106244     0.356440  0.336165
# 579  100.0  0.123346  0.118761  0.095161  0.103062     0.355277  0.338572
# 29   100.0  0.123713  0.119121  0.091935  0.102860     0.355232  0.337260
# 509  100.0  0.101083  0.114572  0.082258  0.098414     0.263932  0.275431
# 449  100.0  0.088065  0.109620  0.070968  0.095693     0.227917  0.247658
# 429  100.0  0.076287  0.105882  0.066129  0.094089     0.199048  0.229174
#
#      test_r-rank2  rank_std2  combi  \
# 519      0.314320   0.318018     48
# 319      0.284095   0.310698      0
# 299      0.289701   0.303026     16
# 9        0.294563   0.316610     29
# 199      0.280995   0.304990     26
# 129      0.271514   0.298715     19
# 209      0.243451   0.240614     27
# 99       0.268696   0.279982     38
# 229      0.301597   0.318552      9
# 349      0.255533   0.278835      3
# 309      0.270385   0.284077     17
# 379      0.266346   0.268868      6
# 239      0.268021   0.290912     10
# 249      0.245403   0.248146     11
# 399      0.290091   0.292792      8
# 579      0.302477   0.319812     51
# 29       0.255788   0.263899     31
# 139      0.292591   0.315770     20
# 369      0.276144   0.294302      5
# 19       0.259562   0.271980     30
# 359      0.285969   0.320057      4
# 599      0.279479   0.294297     41
# 118      0.276637   0.300059     18
# 149      0.252320   0.277543     21
# 329      0.299571   0.309275      1
# 559      0.289150   0.315014     49
# 569      0.290367   0.308676     50
# 219      0.268915   0.281780     28
# 479      0.274225   0.293669     56
# 409      0.244396   0.260067     61
# ..            ...        ...    ...
# 179      0.233750   0.254510     24
# 279      0.227711   0.235723     14
# 529      0.278065   0.299225     43
# 169      0.240468   0.268163     23
# 39       0.244055   0.266925     32
# 489      0.262201   0.280098     57
# 159      0.244514   0.268065     22
# 339      0.212337   0.244391      2
# 69       0.238604   0.266219     35
# 549      0.218148   0.249636     45
# 499      0.228005   0.262602     46
# 609      0.236511   0.262794     42
# 89       0.254101   0.294645     37
# 619      0.234254   0.255726     52
# 469      0.243878   0.270198     55
# 259      0.236829   0.263316     12
# 49       0.248811   0.276540     33
# 79       0.234103   0.264230     36
# 189      0.248119   0.274404     25
# 459      0.237038   0.257540     60
# 289      0.237405   0.252041     15
# 419      0.206187   0.248089     62
# 639      0.222831   0.259772     54
# 629      0.206709   0.240063     53
# 539      0.237128   0.272721     44
# 439      0.226440   0.271172     58
# 59       0.233136   0.257458     34
# 509      0.235482   0.269487     47
# 449      0.211601   0.243461     59
# 429      0.188840   0.229487     63
#
#                                               features  combination
# 519  ('broadcaster', 'description_tfidf', 'genres',...           48
# 319                                               None            0
# 299                    ('description_tfidf', 'genres')           16
# 9             ('broadcaster', 'genres', 'title_tfidf')           29
# 199     ('broadcaster', 'description_tfidf', 'genres')           26
# 129                          ('genres', 'title_tfidf')           19
# 209  ('broadcaster', 'description_tfidf', 'title_tf...           27
# 99      ('description_tfidf', 'genres', 'title_tfidf')           38
# 229                          ('broadcaster', 'genres')            9
# 349                             ('description_tfidf',)            3
# 309               ('description_tfidf', 'title_tfidf')           17
# 379                                     ('sub_tfidf',)            6
# 239                     ('broadcaster', 'title_tfidf')           10
# 249                       ('broadcaster', 'sub_tfidf')           11
# 399               ('broadcaster', 'description_tfidf')            8
# 579  ('broadcaster', 'genres', 'title_tfidf', 'sub_...           51
# 29         ('broadcaster', 'title_tfidf', 'sub_tfidf')           31
# 139                            ('genres', 'sub_tfidf')           20
# 369                                   ('title_tfidf',)            5
# 19              ('broadcaster', 'genres', 'sub_tfidf')           30
# 359                                        ('genres',)            4
# 599             ('genres', 'title_tfidf', 'sub_tfidf')           41
# 118                 ('description_tfidf', 'sub_tfidf')           18
# 149                       ('title_tfidf', 'sub_tfidf')           21
# 329                                   ('broadcaster',)            1
# 559  ('broadcaster', 'description_tfidf', 'genres',...           49
# 569  ('broadcaster', 'description_tfidf', 'title_tf...           50
# 219  ('broadcaster', 'description_tfidf', 'sub_tfidf')           28
# 479  ('description_tfidf', 'genres', 'title_tfidf',...           56
# 409  ('broadcaster', 'description_tfidf', 'genres',...           61
# ..                                                 ...          ...
# 179          ('broadcaster', 'credits', 'title_tfidf')           24
# 279                         ('credits', 'title_tfidf')           14
# 529  ('broadcaster', 'credits', 'description_tfidf'...           43
# 169               ('broadcaster', 'credits', 'genres')           23
# 39          ('credits', 'description_tfidf', 'genres')           32
# 489  ('broadcaster', 'credits', 'description_tfidf'...           57
# 159    ('broadcaster', 'credits', 'description_tfidf')           22
# 339                                       ('credits',)            2
# 69                ('credits', 'genres', 'title_tfidf')           35
# 549  ('broadcaster', 'credits', 'genres', 'title_tf...           45
# 499  ('broadcaster', 'credits', 'genres', 'sub_tfidf')           46
# 609  ('broadcaster', 'credits', 'description_tfidf'...           42
# 89             ('credits', 'title_tfidf', 'sub_tfidf')           37
# 619  ('credits', 'description_tfidf', 'genres', 'ti...           52
# 469  ('credits', 'genres', 'title_tfidf', 'sub_tfidf')           55
# 259                   ('credits', 'description_tfidf')           12
# 49     ('credits', 'description_tfidf', 'title_tfidf')           33
# 79                  ('credits', 'genres', 'sub_tfidf')           36
# 189            ('broadcaster', 'credits', 'sub_tfidf')           25
# 459  ('broadcaster', 'credits', 'genres', 'title_tf...           60
# 289                           ('credits', 'sub_tfidf')           15
# 419  ('credits', 'description_tfidf', 'genres', 'ti...           62
# 639  ('credits', 'description_tfidf', 'title_tfidf'...           54
# 629  ('credits', 'description_tfidf', 'genres', 'su...           53
# 539  ('broadcaster', 'credits', 'description_tfidf'...           44
# 439  ('broadcaster', 'credits', 'description_tfidf'...           58
# 59       ('credits', 'description_tfidf', 'sub_tfidf')           34
# 509  ('broadcaster', 'credits', 'title_tfidf', 'sub...           47
# 449  ('broadcaster', 'credits', 'description_tfidf'...           59
# 429  ('broadcaster', 'credits', 'description_tfidf'...           63
#
# [64 rows x 12 columns]

# %%
high_base = [0, 48]
df_50_rr = df[df['combination'].isin(high_base)].copy()
f, axes = plt.subplots(1, 2, figsize=(16,3))
ax = sns.lineplot(x="epoch", y="test_p5",data=df_50_rr, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[0])
axes[0].set_title("Mean precision@5 for baseline and top combination")
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df_50_rr, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[1])
axes[1].set_title("Mean reciprocal rank for baseline and top combination")
plt.show()

# %%
# highest mean reciprocal rank
rr52 = df.groupby(['combination'])['test_r-rank2'].transform(max) == df['test_r-rank2']
df_rr52 = df[rr52].copy()
df_rr52.sort_values('test_r-rank2', ascending=False)
df_rr52.loc[df_rr52['test_r-rank2'].idxmax()]
# Out:
# epoch                                                         100
# test_p5                                                  0.125775
# p5_std                                                   0.118789
# test_p52                                                  0.11129
# p5_std2                                                  0.102556
# test_r-rank                                              0.367717
# rank_std                                                 0.345132
# test_r-rank2                                              0.31432
# rank_std2                                                0.318018
# combi                                                          48
# features        ('broadcaster', 'description_tfidf', 'genres',...
# combination                                                    48
# Name: 519, dtype: object

# %%
high_base = [0, 48]
df_41_rr = df[df['combination'].isin(high_base)].copy()
f, axes = plt.subplots(1, 2, figsize=(16,3))
ax = sns.lineplot(x="epoch", y="test_p52",data=df_41_rr, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[0])
axes[0].set_title("Mean precision@5 for baseline and top combination")
ax = sns.lineplot(x="epoch", y="test_r-rank2",data=df_41_rr, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[1])
axes[1].set_title("Mean reciprocal rank for baseline and top combination")
plt.show()

# %%
high_base1 = [0, 48]
df_rank1 = df[df['combination'].isin(high_base1)].copy()
high_base2 = [0, 48]
df_rank2 = df[df['combination'].isin(high_base2)].copy()

f, axes = plt.subplots(1, 2, figsize=(16,3))
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df_rank1, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[0])
axes[0].set_title("MRR for baseline and top combination (Test 1)")
axes[0].set(ylabel='mrr')
ax = sns.lineplot(x="epoch", y="test_r-rank2",data=df_rank2, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[1])
axes[1].set_title("MRR for baseline and top combination (Test 2)")
axes[1].set(ylabel='mrr')
plt.show()

# %% [markdown]
# ## RQ3

# %%
f, axes = plt.subplots(1, 1, figsize=(7,8))
ax = sns.lineplot(x="epoch", y="test_p5",data=df, hue='combination', ax=axes)
axes.set(ylabel='mean p@5')
axes.axhline(0.008, ls='--')
axes.text(85, 0.005, "current p@5")
plt.show()

# %%
f, axes = plt.subplots(1, 1, figsize=(7,8))
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df, hue='combination', ax=axes)
axes.set(ylabel='mrr')
axes.axhline(0.024, ls='--')
axes.text(85, 0.015, "current mrr")
plt.show()

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))
ax = sns.lineplot(x="epoch", y="test_p5",data=df, hue='combination', ax=axes[0])
axes[0].set_title("Mean p@5 for all content feature combinations")
axes[0].set(ylabel='mean p@5')
axes[0].axhline(0.008, ls='--')
axes[0].text(85, 0.005, "current p@5")
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df, hue='combination', ax=axes[1])
axes[1].set_title("MRR for all content feature combinations")
axes[1].set(ylabel='mrr')
axes[1].axhline(0.024, ls='--')
axes[1].text(85, 0.015, "current mrr")
plt.show()

# %%
f, axes = plt.subplots(1, 1, figsize=(7,8))
ax = sns.lineplot(x="epoch", y="test_p52",data=df, hue='combination', ax=axes)
axes.set(ylabel='mean p@5')
axes.axhline(0.008, ls='--')
axes.text(85, 0.005, "current p@5")
plt.show()

# %%
f, axes = plt.subplots(1, 1, figsize=(7,8))
ax = sns.lineplot(x="epoch", y="test_r-rank2",data=df, hue='combination', ax=axes)
axes.set(ylabel='mrr')
axes.axhline(0.024, ls='--')
axes.text(85, 0.015, "current mrr")
plt.show()

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))
ax = sns.lineplot(x="epoch", y="test_p52",data=df, hue='combi', ax=axes[0])
axes[0].set_title("Mean p@5 for all content feature combinations")
axes[0].set(ylabel='mean p@5')
axes[0].axhline(0.008, ls='--')
axes[0].text(85, 0.005, "current p@5")
ax = sns.lineplot(x="epoch", y="test_r-rank2",data=df, hue='combi', ax=axes[1])
axes[1].set_title("MRR for all content feature combinations")
axes[1].set(ylabel='mrr')
axes[1].axhline(0.024, ls='--')
axes[1].text(85, 0.015, "current mrr")
plt.show()

# %% [markdown]
# ### Standard deviation
#
# (Is there a relation between high precision/ r-rank and low std?)

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))
ax = sns.lineplot(x="epoch", y="p5_std",data=df, hue='combi', ax=axes[0])
axes[0].set_title("Mean STD precision@5 for all content feature combinations")
ax = sns.lineplot(x="epoch", y="rank_std",data=df, hue='combi', ax=axes[1])
axes[1].set_title("Mean STD reciprocal rank for all content feature combinations")
plt.show()

# %%
p5_std = df.groupby(['combi'])['p5_std'].transform(min) == df['p5_std']
df_p5_std = df[p5_std].copy()
print(df_p5_std.loc[df_p5_std['p5_std'].idxmax()])
print(combi[19])
# Out:
# epoch                  10
# test_p5         0.0962059
# p5_std           0.113375
# test_p52        0.0806452
# p5_std2         0.0981091
# test_r-rank      0.254884
# rank_std         0.273036
# test_r-rank2     0.221636
# rank_std2        0.246162
# combi                   0
# features             None
# combination             0
# Name: 310, dtype: object
# ('genres', 'title_tfidf')

# %%
rr5_std = df.groupby(['combi'])['rank_std'].transform(min) == df['rank_std']
df_rr5_std = df[rr5_std].copy()
print(df_rr5_std.loc[df_rr5_std['rank_std'].idxmax()])
print(combi[19])
# Out:
# epoch                                  10
# test_p5                         0.0905966
# p5_std                           0.110879
# test_p52                        0.0741936
# p5_std2                         0.0966128
# test_r-rank                      0.249505
# rank_std                         0.280332
# test_r-rank2                     0.218287
# rank_std2                        0.263565
# combi                                   9
# features        ('broadcaster', 'genres')
# combination                             9
# Name: 220, dtype: object
# ('genres', 'title_tfidf')
