# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Preparations

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pyspark.sql.functions as sf

plt.style.use('bmh')
pd.options.display.max_columns = 500

# %%
poms = spark.read.parquet("gs://dataproc-jupyter-eileen.npo-data.nl/data/poms_stream/")
print(poms.count())
poms.printSchema()
# Out:
# 83886
# root
#  |-- age_rating: string (nullable = true)
#  |-- credits: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- family_name: string (nullable = true)
#  |    |    |-- given_name: string (nullable = true)
#  |    |    |-- role: string (nullable = true)
#  |-- genres: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- terms: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |-- mid: string (nullable = true)
#  |-- broadcaster: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- sub: string (nullable = true)
#  |-- seriesRef: string (nullable = true)

# %%
def replace(column, value):
    return sf.when(sf.size(column) > value, column).otherwise(sf.lit(None))
def replace2(column, value):
    return sf.when(column != value, column).otherwise(sf.lit(None))

poms = poms.withColumn("credits", replace(sf.col("credits"), 0))
poms = poms.withColumn("genres", replace(sf.col("genres"), 0))
poms = poms.withColumn("sub", replace2(sf.col("sub"), ""))

df = poms.toPandas()

# %%
df = df.rename(columns = {"sub" : "subtitles", "seriesRef" : "series_reference"})
df = df.reindex(sorted(df.columns), axis=1)
df.head()
# Out:
#   age_rating broadcaster                                            credits  \
# 0        ALL        AVTR                      [(van Osch, Frank, DIRECTOR)]
# 1         12        AVTR  [(van Rijn, Pieter, DIRECTOR), (Roelfsema, Mar...
# 2        ALL        AVTR                          [(Niehe, Ivo, PRESENTER)]
# 3        ALL        AVTR  [(van Brakel, Maurits, ACTOR), (Kroes, Olie, A...
# 4        ALL        AVTR  [(Caspers, Charlotte, PRESENTER), (Dik, Joris,...
#
#                                          description  \
# 0  Regisseur Frank van Osch ging met fotograaf Ja...
# 1  Wolfs en Eva krijgen een zaak waarbij 2 lijken...
# 2  Een gesprek met Rob Scholte en een eerbetoon a...
# 3  Lieke moet van haar moeder netjes blijven. Dat...
# 4  Op 12 oktober 1654 kwam Fabritius om het leven...
#
#                                           genres         mid  \
# 0  [(3.0.1.8.24, [Documentaire, Kunst/cultuur])]  AT_2054679
# 1              [(3.0.1.3.10, [Serie, Spanning])]  AT_2061068
# 2                       [(3.0.1.6, [Amusement])]  AT_2066759
# 3                  [(3.0.1.1.3, [Jeugd, Serie])]  AT_2071463
# 4   [(3.0.1.7.24, [Informatief, Kunst/cultuur])]  AT_2083070
#
#      series_reference                                          subtitles  \
# 0  POMS_S_AVRO_096892  888 terugkerend thema in het werk van fotograa...
# 1          AT_2037214  888 mooi! u werkt daar belangeloos aan mee? 20...
# 2          AT_2048922  888 goedenavond. straks het levensverhaal van ...
# 3          AT_2049785  888 oeh! o, doe dat maar niet. hoi. een hele g...
# 4          AT_2051673  888 door het maken van een reconstructie probe...
#
#                        title
# 0                   Close Up
# 1         Flikken Maastricht
# 2                    TV Show
# 3                  Mees Kees
# 4  Het geheim van de Meester

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83886 entries, 0 to 83885
# Data columns (total 9 columns):
# age_rating          83886 non-null object
# broadcaster         83886 non-null object
# credits             30541 non-null object
# description         70836 non-null object
# genres              72427 non-null object
# mid                 83886 non-null object
# series_reference    83886 non-null object
# subtitles           35068 non-null object
# title               83886 non-null object
# dtypes: object(9)
# memory usage: 5.8+ MB

# %%
test = df.isna().sum()
df2 = pd.DataFrame({'values':test.index, 'na_count':test.values})
df2['count'] = poms.count() - df2['na_count']

plt.figure(figsize = (9,4))
ax = sns.barplot(x='values', y ='count', data=df2)#.set_title('Count of non-NaN values')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Visualizing data distribution

# %%
df['age_rating'] = df['age_rating'].astype('category')
df['credits'] = df['credits'].astype('string').astype('category')
df['genres'] = df['genres'].astype('string').astype('category')
df['broadcaster'] = df['broadcaster'].astype('category')
df.dtypes
# Out:
# age_rating          category
# broadcaster         category
# credits             category
# description           object
# genres              category
# mid                   object
# series_reference      object
# subtitles             object
# title                 object
# dtype: object

# %%
plt.figure(figsize = (5,4))
ax = sns.countplot(x="age_rating", data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize = (12,4))
ax = sns.countplot(x="broadcaster", data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Text length (includes 0 values)

# %%
# amount of characters, not words
df['title_length'] = df.title.str.split().apply(len)
df['description'] = df['description'].fillna('')
df['description_length'] = df.description.str.split().apply(len)
df['title_length'] = df['title_length'].fillna(0)
df['description_length'] = df['description_length'].fillna(0)

# %%
print("Title length")
print("Mean " + str(df['title_length'].mean()))
print("Median " + str(df['title_length'].median()))
print("\nDescription length")
print("Mean " + str(df['description_length'].mean()))
print("Median " + str(df['description_length'].median()))
# Out:
# Title length
# Mean 2.49010561953
# Median 2.0
#
# Description length
# Mean 20.7481224519
# Median 18.0

# %%
df['subtitles'] = df['subtitles'].fillna('')
df['sub_length'] = df['subtitles'].str.split().apply(len)
df['sub_length'] = df['sub_length'].fillna(0)

# %%
print("Mean " + str(df['sub_length'].mean()))
print("Median " + str(df['sub_length'].median()))
# Out:
# Mean 1038.59391317
# Median 0.0

# %% [markdown]
# - Title, description and subtitle (character) length al have a skewed distribution

# %%
test = ['title_length', 'description_length', 'sub_length']
fig, ax = plt.subplots(1, 3, figsize = (12,4))

for i, ax in enumerate(fig.axes):
    if i < len(test):
        sns.distplot(df[test[i]], ax=ax)   
        #ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
    
fig.tight_layout()

# %% [markdown]
# ### Broadcaster richness investigation

# %%
def length(df):
    sub_extra = []
    for index, row in df.iterrows():
        doc = row['description_length'] > 0
        sub_extra.append(doc)
    df['length'] = sub_extra

test = df.copy()
length(test)

# %%
broadcaster = df.broadcaster.unique().tolist()
pd_test = pd.DataFrame(broadcaster, columns=['broadcaster'])
true_ = []
false_ = []
count_ = []
for i in broadcaster:
    test2 = test[test['broadcaster'] == i]
    count = len(test2['length'])
    count_.append(count)
    true = sum(test2['length'] == True)
    false = sum(test2['length'] == False)
    true_.append(true)
    false_.append(false)
pd_test['count'] = count_
pd_test['true'] = true_
pd_test['false'] = false_
#pd_test

# %%
plt.figure(figsize = (16,5))
ax = sns.lineplot(x="broadcaster", y="count",data=pd_test, label="count")
#ax = sns.lineplot(x="broadcaster", y="true",data=pd_test, label="true")
ax = sns.lineplot(x="broadcaster", y="false",data=pd_test, label="none")
plt.xticks(rotation=45)
plt.title("Richness per broadcaster")
plt.ylabel("count")
plt.show()

# %% [markdown]
# ### Series investigation

# %%
print(len(df.series_reference.unique()))
df.series_reference.value_counts()
# Out:
# NOSJournaal               10297
# NOSJeugdjournaal           3088
# AT_2046031                 2160
# VPWON_1256937              2050
# NOSJournaalgebarentolk     2023
# KN_1676932                 1692
# VPWON_1256934              1602
# POMS_S_NCRV_059865         1474
# AT_2037144                 1125
# NOSjeugd0845geb            1099
# VPWON_1257894              1038
# POW_03333061                999
# VARA_101377717              956
# NOSSportRegulier            950
# POW_03108338                932
# NOSjnl2000                  836
# KN_1677095                  782
# VPWON_1246712               721
# POMS_S_KRO_059857           696
# POW_03108298                540
# POMS_S_VARA_059932          501
# VPWON_1257901               464
# KN_1676721                  453
# POW_03469040                435
# VPWON_1259670               435
# KN_1677083                  434
# AT_2035122                  433
# VPWON_1257896               421
# POMS_S_AVRO_096997          421
# VPWON_1256936               402
#                           ...
# POMS_S_BOS_126341             1
# POW_03545866                  1
# POMS_S_EO_13546132            1
# POMS_S_AVRO_416035            1
# POMS_S_NOS_351010             1
# POMS_S_POWN_15030043          1
# POMS_S_AT_11910360            1
# POMS_S_AT_9033129             1
# POMS_S_OHM_358869             1
# POMS_S_BNN_123477             1
# POMS_S_AVRO_120098            1
# POMS_S_AVRO_120097            1
# POMS_S_BNN_215973             1
# POMS_S_AT_15123852            1
# POMS_S_BV_15028702            1
# RBX_S_VPRO_553850             1
# POMS_S_VPRO_084045            1
# POMS_S_NOS_123139             1
# POMS_S_VARA_9449421           1
# POMS_S_EO_13076944            1
# POMS_S_TROS_123412            1
# POMS_S_TROS_100084            1
# POMS_S_VPRO_310047            1
# POMS_S_VARA_099811            1
# POMS_S_TROS_100082            1
# POMS_S_NOS_4316773            1
# Onbekend_282                  1
# POMS_S_NOS_104831             1
# POMS_S_BV_14824696            1
# POMS_S_KRO_123982             1
# Name: series_reference, Length: 2490, dtype: int64

# %%
grouped = df.groupby('series_reference')
grouped_df = grouped.mean()
grouped_df
# Out:
#                    title_length  description_length   sub_length
# series_reference
# 12Jnl0730n1            2.000000            2.785714    50.654762
# 12Jnl0730n2            4.000000            0.000000    50.963415
# 12Jnl0830n1            2.000000            2.821429    52.226190
# 12Jnl0830n2            2.000000            0.000000    51.695122
# 12stspEreVrijdag       4.000000           10.000000     0.000000
# 12stspSuperCup         4.400000           12.200000     0.000000
# 12stspVoetbal          3.000000           10.842105   427.842105
# 12stspVoetbalHH        3.000000            7.000000     0.000000
# 13Jnl1200n2            2.000000            0.000000  1174.000000
# 13JnlFlits             2.000000            0.000000  6182.000000
# 13stsp1810ZoR          3.034483            6.172414  2452.137931
# 13stspEKvr1            6.600000           12.000000  1826.000000
# 13stspEKvr2            6.600000            7.200000  1149.600000
# 13stspEKvrNB           5.000000            0.000000  1196.500000
# 13stspEKvrVB           6.000000            0.000000  3845.666667
# 13stspEKvrWA           5.600000            7.400000     0.000000
# 13stspGS1310           3.125000           12.166667  9023.375000
# 13stspGS1400           3.120000           11.000000     0.000000
# 13stspGSextra          3.166667           17.666667  1555.444444
# 13stspSuperCup         6.000000            6.000000  1763.000000
# 13stspUCL1ste         10.500000            9.166667  1014.291667
# 13stspUCL2de          10.500000            9.166667  1245.333333
# 13stspUCLMagazine      5.000000            9.000000  1226.000000
# 13stspUCLnb            7.375000           18.916667   593.750000
# 13stspUCLsv            5.000000            6.500000   766.000000
# 13stspUCLvb            8.958333           12.708333  3511.083333
# 13stspUCLwa            8.916667           36.291667     0.000000
# 13stspVoetbal          3.000000            7.000000  2933.724138
# 13stspZaR              3.000000            5.250000  1707.527778
# 13stspjnl1845          2.000000            5.000000   692.264368
# ...                         ...                 ...          ...
# VPWON_1296192          3.000000           25.000000     0.000000
# VPWON_1296199          1.833333           18.666667   421.000000
# VPWON_1296820          1.000000           13.333333  5028.666667
# VPWON_1297190          1.000000            8.000000     0.000000
# VPWON_1297243          5.000000           21.666667     0.000000
# VPWON_1297780          4.000000           16.000000     0.000000
# VPWON_1297781          5.000000           17.333333   887.666667
# VPWON_1297819          4.000000           19.000000  1445.500000
# VPWON_1297848          2.000000           20.250000  3560.500000
# VPWON_1297866          7.666667           18.666667     0.000000
# VPWON_1298134          4.000000           21.000000     0.000000
# VPWON_1298270          4.000000           15.523810  1521.333333
# VPWON_1298329          4.000000           24.500000  6118.750000
# VPWON_1298406          2.000000           23.500000  2251.250000
# VPWON_1298438          1.000000           20.000000     0.000000
# VPWON_1298543          4.000000           20.166667  6514.166667
# VPWON_1298926          3.000000           23.250000  1401.375000
# VPWON_1299265          2.000000           23.000000  1300.000000
# VPWON_1301039          2.000000           13.500000     0.000000
# VPWON_1301135          3.000000           18.750000  8023.750000
# VPWON_1301489          3.000000           18.857143   629.000000
# VPWON_1301610          6.000000           22.000000     0.000000
# VPWON_1301735          2.000000           16.500000     0.000000
# VPWON_1301872          2.000000           20.125000     0.000000
# VPWON_1303034          4.000000           20.000000     0.000000
# VPWON_1303042          6.000000           20.000000     0.000000
# VPWON_1303418          4.000000           19.800000   118.800000
# VPWON_1304001          4.000000           24.000000     0.000000
# VPWON_1304100          7.000000           16.000000  2252.666667
# VPWON_1304972          1.500000           21.875000     0.000000
#
# [2490 rows x 3 columns]

# %%
test = ['title_length', 'description_length', 'sub_length']
fig, ax = plt.subplots(1, 3, figsize = (12,4))

for i, ax in enumerate(fig.axes):
    if i < len(test):
        #ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
        sns.distplot(grouped_df[test[i]], ax=ax)    
    
fig.tight_layout()

# %%
print("Title length")
print("Mean " + str(grouped_df['title_length'].mean()))
print("Median " + str(grouped_df['title_length'].median()))
print("\nDescription length")
print("Mean " + str(grouped_df['description_length'].mean()))
print("Median " + str(grouped_df['description_length'].median()))
print("\nSubtitles length")
print("Mean " + str(grouped_df['sub_length'].mean()))
print("Median " + str(grouped_df['sub_length'].median()))
# Out:
# Title length
# Mean 3.28597462119
# Median 3.0
#
# Description length
# Mean 27.579924905
# Median 22.0
#
# Subtitles length
# Mean 1687.02773121
# Median 500.727020227
