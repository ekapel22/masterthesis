# %% [markdown]
# ## Results

# %%
# %matplotlib inline
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pyspark.sql.functions as sf

plt.style.use('bmh')
pd.options.display.max_columns = 500

# %%
parts = ['0-22', '22-38', '38-64'] 

paths = []
for i in range(0, len(parts)):
    paths.append('gs://dataproc-jupyter-eileen.npo-data.nl/data/results/results' + parts[i])
results_df = spark.read.parquet(*paths)

# %%
features = ['broadcaster', 'credits', 'description_tfidf', 'genres', 'title_tfidf', 'sub_tfidf']

def combinations(features):
    combi = []
    for i in range(1, len(features)+1):
        combi = combi + list(itertools.combinations(features,i))
    return combi

combi = combinations(features)
combi.insert(0, None)
print(len(combi))
# Out:
# 64

# %%
df = results_df.toPandas()
df.columns = ['epoch', 'train_p5', 'test_p5', 'p5_std', 'train_r-rank', 'test_r-rank', 'rank_std']
indeces = []
features = []
df = df.dropna()
for i in range(0, len(combi)):
    for j in range(0, 10):
        indeces.append(i)
        features.append(str(combi[i]))
df['combi'] = indeces
df['features'] = features
df
# Out:
#      epoch  train_p5   test_p5    p5_std  train_r-rank  test_r-rank  rank_std  \
# 0     10.0  0.216880  0.058540  0.095987      0.553112     0.161482  0.226089
# 1     20.0  0.226018  0.060473  0.097372      0.565638     0.163970  0.222097
# 2     30.0  0.247191  0.064120  0.100704      0.574802     0.165837  0.219762
# 3     40.0  0.267395  0.064722  0.101303      0.590563     0.165653  0.217281
# 4     50.0  0.287412  0.061947  0.099375      0.603668     0.159770  0.212000
# 5     60.0  0.301943  0.062766  0.100661      0.614628     0.160367  0.211540
# 6     70.0  0.315522  0.061526  0.099636      0.625612     0.157625  0.209737
# 7     80.0  0.325113  0.059864  0.098522      0.633753     0.154918  0.207391
# 8     90.0  0.333698  0.058638  0.097891      0.641006     0.152935  0.206371
# 9    100.0  0.341486  0.058548  0.097960      0.649350     0.153074  0.206792
# 11    10.0  0.028531  0.005489  0.032814      0.081440     0.032392  0.130683
# 12    20.0  0.034283  0.005745  0.033809      0.093988     0.035044  0.127436
# 13    30.0  0.041213  0.006790  0.036757      0.107851     0.039862  0.127848
# 14    40.0  0.050328  0.009776  0.044156      0.119561     0.044902  0.130849
# 15    50.0  0.059177  0.011400  0.047458      0.133034     0.048881  0.132171
# 16    60.0  0.068121  0.013257  0.050921      0.147972     0.053550  0.135252
# 17    70.0  0.074005  0.014987  0.053982      0.155540     0.057197  0.136511
# 18    80.0  0.081778  0.019175  0.060347      0.162597     0.063162  0.141743
# 19    90.0  0.086944  0.020431  0.062115      0.168896     0.065641  0.142355
# 20   100.0  0.091221  0.021551  0.063571      0.175478     0.067935  0.143160
# 22    10.0  0.024263  0.005256  0.032135      0.076039     0.034360  0.126830
# 23    20.0  0.029835  0.005196  0.031910      0.089538     0.038996  0.124419
# 24    30.0  0.039785  0.008242  0.040429      0.108845     0.044798  0.125967
# 25    40.0  0.049657  0.009369  0.043038      0.122320     0.049273  0.126023
# 26    50.0  0.061963  0.012054  0.048598      0.163267     0.050294  0.101367
# 27    60.0  0.070844  0.014776  0.053453      0.185168     0.056528  0.109877
# 18       1                                   ('broadcaster',)
# 19       1                                   ('broadcaster',)
# 20       1                                   ('broadcaster',)
# 22       2                                       ('credits',)
# 23       2                                       ('credits',)
# 24       2                                       ('credits',)
# 25       2                                       ('credits',)
# 26       2                                       ('credits',)
# 27       2                                       ('credits',)
# 28       2                                       ('credits',)
# 29       2                                       ('credits',)
# 30       2                                       ('credits',)
# 31       2                                       ('credits',)
# ..     ...                                                ...
# 671     61  ('broadcaster', 'description_tfidf', 'genres',...
# 672     61  ('broadcaster', 'description_tfidf', 'genres',...
# 673     61  ('broadcaster', 'description_tfidf', 'genres',...
# 674     61  ('broadcaster', 'description_tfidf', 'genres',...
# 675     61  ('broadcaster', 'description_tfidf', 'genres',...
# 676     61  ('broadcaster', 'description_tfidf', 'genres',...
# 677     61  ('broadcaster', 'description_tfidf', 'genres',...
# 678     61  ('broadcaster', 'description_tfidf', 'genres',...
# 679     61  ('broadcaster', 'description_tfidf', 'genres',...
# 680     61  ('broadcaster', 'description_tfidf', 'genres',...
# 682     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 683     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 684     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 685     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 686     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 687     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 688     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 689     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 690     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 691     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 693     63  ('broadcaster', 'credits', 'description_tfidf'...
# 694     63  ('broadcaster', 'credits', 'description_tfidf'...
# 695     63  ('broadcaster', 'credits', 'description_tfidf'...
# 696     63  ('broadcaster', 'credits', 'description_tfidf'...
# 697     63  ('broadcaster', 'credits', 'description_tfidf'...
# 698     63  ('broadcaster', 'credits', 'description_tfidf'...
# 699     63  ('broadcaster', 'credits', 'description_tfidf'...
# 700     63  ('broadcaster', 'credits', 'description_tfidf'...
# 701     63  ('broadcaster', 'credits', 'description_tfidf'...
# 702     63  ('broadcaster', 'credits', 'description_tfidf'...
#
# [640 rows x 9 columns]

# %%
spark.createDataFrame(df).write.parquet('gs://dataproc-jupyter-eileen.npo-data.nl/data/results/results_RUN1')

# %% [markdown]
# ## Results

# %%
df = spark.read.parquet('gs://dataproc-jupyter-eileen.npo-data.nl/data/results/results_RUN1')
df = df.toPandas()

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))
ax = sns.lineplot(x="epoch", y="test_p5",data=df, hue='combi', ax=axes[0])
axes[0].set_title("Mean precision@5 for all content feature combinations")
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df, hue='combi', ax=axes[1])
axes[1].set_title("Mean reciprocal rank for all content feature combinations")
plt.show()

# %%
# highest mean p@k
p5 = df.groupby(['combi'])['test_p5'].transform(max) == df['test_p5']
df_p5 = df[p5].copy()
df_p5.sort_values('test_p5', ascending=False)
# Out:
#      epoch  train_p5   test_p5    p5_std  train_r-rank  test_r-rank  rank_std  \
# 163   40.0  0.252099  0.068436  0.103529      0.576538     0.175401  0.224504
# 530   10.0  0.307367  0.067489  0.102166      0.630988     0.170791  0.216670
# 561   20.0  0.287077  0.066429  0.102206      0.611592     0.170163  0.221113
# 13    40.0  0.269315  0.066233  0.102097      0.593049     0.169667  0.220348
# 5     60.0  0.298666  0.065428  0.102739      0.614544     0.168934  0.221591
# 131   20.0  0.273256  0.065331  0.101246      0.597665     0.169753  0.222485
# 231   20.0  0.262533  0.065293  0.101515      0.592055     0.169412  0.222366
# 263   40.0  0.272616  0.065263  0.101283      0.595000     0.167495  0.219146
# 359  100.0  0.059435  0.011325  0.047286      0.132822     0.052291  0.122973
# 299  100.0  0.067005  0.010204  0.044416      0.155661     0.051959  0.146446
# 49   100.0  0.045880  0.007805  0.039463      0.114392     0.043274  0.123224
# 31    20.0  0.023506  0.006617  0.035982      0.066507     0.028343  0.123848
# 29   100.0  0.033050  0.006565  0.036054      0.095730     0.039256  0.131405
# 439  100.0  0.037342  0.005820  0.033974      0.102733     0.040804  0.120003
# 229  100.0  0.029569  0.004737  0.030759      0.081857     0.031932  0.116693
# 389  100.0  0.024013  0.004346  0.029316      0.075446     0.028908  0.113614
# 409  100.0  0.029210  0.004226  0.028920      0.083197     0.035472  0.112777
# 219  100.0  0.017543  0.004151  0.028775      0.061088     0.026281  0.110224
# 70    10.0  0.007593  0.003241  0.025431      0.029243     0.019281  0.115706
# 190   10.0  0.004269  0.002812  0.023613      0.026309     0.018955  0.114660
#
#      combi                                           features
# 163     16                    ('description_tfidf', 'genres')
# 530     37            ('credits', 'title_tfidf', 'sub_tfidf')
# 561     40  ('description_tfidf', 'title_tfidf', 'sub_tfidf')
# 13      49  ('broadcaster', 'description_tfidf', 'genres',...
# 5       48  ('broadcaster', 'description_tfidf', 'genres',...
# 131     61  ('broadcaster', 'description_tfidf', 'genres',...
# 231     23               ('broadcaster', 'credits', 'genres')
# 263     26     ('broadcaster', 'description_tfidf', 'genres')
# 524     36                 ('credits', 'genres', 'sub_tfidf')
# 323      0                                               None
# 121     60  ('broadcaster', 'credits', 'genres', 'title_tf...
# 311     31        ('broadcaster', 'title_tfidf', 'sub_tfidf')
# 580     42  ('broadcaster', 'credits', 'description_tfidf'...
# 479     15                           ('credits', 'sub_tfidf')
# 148     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 593     43  ('broadcaster', 'credits', 'description_tfidf'...
# 482     32         ('credits', 'description_tfidf', 'genres')
# 451     13                              ('credits', 'genres')
# 500     34      ('credits', 'description_tfidf', 'sub_tfidf')
# 611     45  ('broadcaster', 'credits', 'genres', 'title_tf...
# 498     33    ('credits', 'description_tfidf', 'title_tfidf')
# 513     35               ('credits', 'genres', 'title_tfidf')
# 249     24          ('broadcaster', 'credits', 'title_tfidf')
# 630     47  ('broadcaster', 'credits', 'title_tfidf', 'sub...
# 570     41             ('genres', 'title_tfidf', 'sub_tfidf')
# 150     63  ('broadcaster', 'credits', 'description_tfidf'...
# 469     14                         ('credits', 'title_tfidf')
# 620     46  ('broadcaster', 'credits', 'genres', 'sub_tfidf')
# 257     25            ('broadcaster', 'credits', 'sub_tfidf')
# 379      5                                   ('title_tfidf',)
# ..     ...                                                ...
# 99      57  ('broadcaster', 'credits', 'description_tfidf'...
# 209     20                            ('genres', 'sub_tfidf')
# 119     59  ('broadcaster', 'credits', 'description_tfidf'...
# 109     58  ('broadcaster', 'credits', 'description_tfidf'...
# 309     30             ('broadcaster', 'genres', 'sub_tfidf')
# 449     12                   ('credits', 'description_tfidf')
# 69      54  ('credits', 'description_tfidf', 'title_tfidf'...
# 609     44  ('broadcaster', 'credits', 'description_tfidf'...
# 419      9                          ('broadcaster', 'genres')
# 289     28  ('broadcaster', 'description_tfidf', 'sub_tfidf')
# 349      2                                       ('credits',)
# 369      4                                        ('genres',)
# 339      1                                   ('broadcaster',)
# 189     18                 ('description_tfidf', 'sub_tfidf')
# 279     27  ('broadcaster', 'description_tfidf', 'title_tf...
# 399      7                         ('broadcaster', 'credits')
# 89      56  ('description_tfidf', 'genres', 'title_tfidf',...
# 559     39       ('description_tfidf', 'genres', 'sub_tfidf')
# 359      3                             ('description_tfidf',)
# 299     29           ('broadcaster', 'genres', 'title_tfidf')
# 49      52  ('credits', 'description_tfidf', 'genres', 'ti...
# 31      51  ('broadcaster', 'genres', 'title_tfidf', 'sub_...
# 29      50  ('broadcaster', 'description_tfidf', 'title_tf...
# 439     11                       ('broadcaster', 'sub_tfidf')
# 229     22    ('broadcaster', 'credits', 'description_tfidf')
# 389      6                                     ('sub_tfidf',)
# 409      8               ('broadcaster', 'description_tfidf')
# 219     21                       ('title_tfidf', 'sub_tfidf')
# 70      55  ('credits', 'genres', 'title_tfidf', 'sub_tfidf')
# 190     19                          ('genres', 'title_tfidf')
#
# [64 rows x 9 columns]

# %%
df_p5.describe()
# Out:
#             epoch   train_p5    test_p5     p5_std  train_r-rank  test_r-rank  \
# count   64.000000  64.000000  64.000000  64.000000     64.000000    64.000000
# mean    67.031250   0.178355   0.041595   0.078318      0.407694     0.116749
# std     38.614073   0.102893   0.023777   0.026220      0.213565     0.053744
# min     10.000000   0.004269   0.002812   0.023613      0.026309     0.018955
# 25%     20.000000   0.083569   0.016820   0.056826      0.176883     0.062829
# 50%    100.000000   0.169686   0.047280   0.088933      0.438373     0.130125
# 75%    100.000000   0.280549   0.063500   0.100250      0.599313     0.164017
# max    100.000000   0.307367   0.068436   0.103529      0.634153     0.175401
#
#         rank_std      combi
# count  64.000000  64.000000
# mean    0.182502  31.500000
# std     0.041060  18.618987
# min     0.108417   0.000000
# 25%     0.143120  15.750000
# 50%     0.200876  31.500000
# 75%     0.218883  47.250000
# max     0.226793  63.000000

# %%
df_p5[df_p5['combi']==0].iloc[0]
# Out:
# epoch                  40
# train_p5         0.267395
# test_p5         0.0647216
# p5_std           0.101303
# train_r-rank     0.590563
# test_r-rank      0.165653
# rank_std         0.217281
# combi                   0
# features             None
# Name: 323, dtype: object

# %%
df_p5.loc[df_p5['test_p5'].idxmax()]
# Out:
# epoch                                    40
# train_p5                           0.252099
# test_p5                           0.0684363
# p5_std                             0.103529
# train_r-rank                       0.576538
# test_r-rank                        0.175401
# rank_std                           0.224504
# combi                                    16
# features        (description_tfidf, genres)
# Name: 163, dtype: object

# %%
# highest MRR
rr5 = df.groupby(['combi'])['test_r-rank'].transform(max) == df['test_r-rank']
df_rr5 = df[rr5].copy()
df_rr5.sort_values('test_r-rank', ascending=False)
# Out:
#      epoch  train_p5   test_p5    p5_std  train_r-rank  test_r-rank  rank_std  \
# 163   40.0  0.252099  0.068436  0.103529      0.576538     0.175401  0.224504
# 310   10.0  0.244092  0.063857  0.099392      0.582001     0.171601  0.226741
# 530   10.0  0.307367  0.067489  0.102166      0.630988     0.170791  0.216670
# 189  100.0  0.078523  0.017190  0.057410      0.162309     0.063543  0.138007
# 279  100.0  0.066896  0.015709  0.055076      0.157881     0.060688  0.142999
# 398   90.0  0.070236  0.013272  0.050888      0.154762     0.056266  0.126765
# 559  100.0  0.085251  0.012092  0.048294      0.177351     0.055066  0.146927
# 89   100.0  0.063961  0.012453  0.049434      0.148287     0.053407  0.141298
# 359  100.0  0.059435  0.011325  0.047286      0.132822     0.052291  0.122973
# 299  100.0  0.067005  0.010204  0.044416      0.155661     0.051959  0.146446
# 49   100.0  0.045880  0.007805  0.039463      0.114392     0.043274  0.123224
# 439  100.0  0.037342  0.005820  0.033974      0.102733     0.040804  0.120003
# 29   100.0  0.033050  0.006565  0.036054      0.095730     0.039256  0.131405
# 39   100.0  0.034158  0.006083  0.034651      0.096723     0.036643  0.124268
# 409  100.0  0.029210  0.004226  0.028920      0.083197     0.035472  0.112777
# 229  100.0  0.029569  0.004737  0.030759      0.081857     0.031932  0.116693
# 389  100.0  0.024013  0.004346  0.029316      0.075446     0.028908  0.113614
# 219  100.0  0.017543  0.004151  0.028775      0.061088     0.026281  0.110224
# 70    10.0  0.007593  0.003241  0.025431      0.029243     0.019281  0.115706
# 190   10.0  0.004269  0.002812  0.023613      0.026309     0.018955  0.114660
#
#      combi                                           features
# 163     16                    ('description_tfidf', 'genres')
# 310     31        ('broadcaster', 'title_tfidf', 'sub_tfidf')
# 530     37            ('credits', 'title_tfidf', 'sub_tfidf')
# 560     40  ('description_tfidf', 'title_tfidf', 'sub_tfidf')
# 524     36                 ('credits', 'genres', 'sub_tfidf')
# 131     61  ('broadcaster', 'description_tfidf', 'genres',...
# 13      49  ('broadcaster', 'description_tfidf', 'genres',...
# 231     23               ('broadcaster', 'credits', 'genres')
# 5       48  ('broadcaster', 'description_tfidf', 'genres',...
# 120     60  ('broadcaster', 'credits', 'genres', 'title_tf...
# 148     62  ('credits', 'description_tfidf', 'genres', 'ti...
# 479     15                           ('credits', 'sub_tfidf')
# 262     26     ('broadcaster', 'description_tfidf', 'genres')
# 450     13                              ('credits', 'genres')
# 322      0                                               None
# 480     32         ('credits', 'description_tfidf', 'genres')
# 514     35               ('credits', 'genres', 'title_tfidf')
# 259     25            ('broadcaster', 'credits', 'sub_tfidf')
# 468     14                         ('credits', 'title_tfidf')
# 498     33    ('credits', 'description_tfidf', 'title_tfidf')
# 610     45  ('broadcaster', 'credits', 'genres', 'title_tf...
# 593     43  ('broadcaster', 'credits', 'description_tfidf'...
# 249     24          ('broadcaster', 'credits', 'title_tfidf')
# 580     42  ('broadcaster', 'credits', 'description_tfidf'...
# 379      5                                   ('title_tfidf',)
# 500     34      ('credits', 'description_tfidf', 'sub_tfidf')
# 570     41             ('genres', 'title_tfidf', 'sub_tfidf')
# 620     46  ('broadcaster', 'credits', 'genres', 'sub_tfidf')
# 150     63  ('broadcaster', 'credits', 'description_tfidf'...
# 630     47  ('broadcaster', 'credits', 'title_tfidf', 'sub...
# ..     ...                                                ...
# 99      57  ('broadcaster', 'credits', 'description_tfidf'...
# 119     59  ('broadcaster', 'credits', 'description_tfidf'...
# 609     44  ('broadcaster', 'credits', 'description_tfidf'...
# 209     20                            ('genres', 'sub_tfidf')
# 109     58  ('broadcaster', 'credits', 'description_tfidf'...
# 309     30             ('broadcaster', 'genres', 'sub_tfidf')
# 449     12                   ('credits', 'description_tfidf')
# 69      54  ('credits', 'description_tfidf', 'title_tfidf'...
# 419      9                          ('broadcaster', 'genres')
# 289     28  ('broadcaster', 'description_tfidf', 'sub_tfidf')
# 349      2                                       ('credits',)
# 369      4                                        ('genres',)
# 339      1                                   ('broadcaster',)
# 189     18                 ('description_tfidf', 'sub_tfidf')
# 279     27  ('broadcaster', 'description_tfidf', 'title_tf...
# 398      7                         ('broadcaster', 'credits')
# 559     39       ('description_tfidf', 'genres', 'sub_tfidf')
# 89      56  ('description_tfidf', 'genres', 'title_tfidf',...
# 359      3                             ('description_tfidf',)
# 299     29           ('broadcaster', 'genres', 'title_tfidf')
# 49      52  ('credits', 'description_tfidf', 'genres', 'ti...
# 439     11                       ('broadcaster', 'sub_tfidf')
# 29      50  ('broadcaster', 'description_tfidf', 'title_tf...
# 39      51  ('broadcaster', 'genres', 'title_tfidf', 'sub_...
# 409      8               ('broadcaster', 'description_tfidf')
# 229     22    ('broadcaster', 'credits', 'description_tfidf')
# 389      6                                     ('sub_tfidf',)
# 219     21                       ('title_tfidf', 'sub_tfidf')
# 70      55  ('credits', 'genres', 'title_tfidf', 'sub_tfidf')
# 190     19                          ('genres', 'title_tfidf')
#
# [64 rows x 9 columns]

# %%
df_rr5.loc[df_rr5['test_r-rank'].idxmax()]
# Out:
# epoch                                    40
# train_p5                           0.252099
# test_p5                           0.0684363
# p5_std                             0.103529
# train_r-rank                       0.576538
# test_r-rank                        0.175401
# rank_std                           0.224504
# combi                                    16
# features        (description_tfidf, genres)
# Name: 163, dtype: object

# %%
high_base = [0, 16]
df_16 = df[df['combi'].isin(high_base)].copy()
f, axes = plt.subplots(1, 2, figsize=(16,3))
ax = sns.lineplot(x="epoch", y="test_p5",data=df_16, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[0])
axes[0].set_title("Mean precision@5 for baseline and top combination")
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df_16, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[1])
axes[1].set_title("Mean reciprocal rank for baseline and top combination")
plt.show()

# %% [markdown]
# ### Standard deviation
#
# (Is there a relation between high precision/ r-rank and low std?)

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))
ax = sns.lineplot(x="epoch", y="p5_std",data=df, hue='combi', ax=axes[0])
axes[0].set_title("Mean STD precision@5 for all content feature combinations")
ax = sns.lineplot(x="epoch", y="rank_std",data=df, hue='combi', ax=axes[1])
axes[1].set_title("Mean STD reciprocal rank for all content feature combinations")
plt.show()

# %%
p5_std = df.groupby(['combi'])['p5_std'].transform(min) == df['p5_std']
df_p5_std = df[p5_std].copy()
print(df_p5_std.loc[df_p5_std['p5_std'].idxmin()])
print(combi[19])
# Out:
# epoch                                  50
# train_p5                        0.0051194
# test_p5                         0.0021807
# p5_std                          0.0209141
# train_r-rank                    0.0234468
# test_r-rank                     0.0154402
# rank_std                        0.0989974
# combi                                  19
# features        ('genres', 'title_tfidf')
# Name: 194, dtype: object
# ('genres', 'title_tfidf')

# %%
rr5_std = df.groupby(['combi'])['rank_std'].transform(min) == df['rank_std']
df_rr5_std = df[rr5_std].copy()
print(df_rr5_std.loc[df_rr5_std['rank_std'].idxmin()])
print(combi[19])
# Out:
# epoch                                  50
# train_p5                        0.0051194
# test_p5                         0.0021807
# p5_std                          0.0209141
# train_r-rank                    0.0234468
# test_r-rank                     0.0154402
# rank_std                        0.0989974
# combi                                  19
# features        ('genres', 'title_tfidf')
# Name: 194, dtype: object
# ('genres', 'title_tfidf')

# %% [markdown]
# ## V2

# %%
parts = ['0-22', '22-40', '40-64']
# parts = ['0-22(2)', '22-28(2)', '28-50(2)', '50-64(2)'] #(2)
# parts = ['0-22(3)', '22-64(3)'] #(3)

paths = []
for i in range(0, len(parts)):
    paths.append('gs://dataproc-jupyter-eileen.npo-data.nl/data/results/marchv2results' + parts[i])
results_df = spark.read.parquet(*paths)

# %%
df = results_df.toPandas()
df.columns = ['epoch', 'test_p5', 'p5_std', 'test_p52', 'p5_std2', 'test_r-rank', 'rank_std', 'test_r-rank2', 'rank_std2']
indeces = []
features = []
df = df.dropna()
for i in range(0, len(combi)):
    for j in range(0, 10):
        indeces.append(i)
        features.append(str(combi[i]))
df['combi'] = indeces
df['features'] = features
df
# Out:
#      epoch   test_p5    p5_std  test_p52   p5_std2  test_r-rank  rank_std  \
# 0     10.0  0.076455  0.106766  0.066129  0.094089     0.201703  0.237882
# 1     20.0  0.093186  0.112687  0.077419  0.100674     0.244959  0.267656
# 2     30.0  0.102310  0.115659  0.080645  0.101344     0.277051  0.293213
# 3     40.0  0.106454  0.116741  0.082258  0.101639     0.284485  0.291666
# 4     50.0  0.109416  0.117243  0.087097  0.102365     0.298015  0.302430
# 5     60.0  0.112468  0.117517  0.090323  0.102721     0.308772  0.309379
# 6     70.0  0.115642  0.118109  0.090323  0.102721     0.326090  0.323670
# 7     80.0  0.117609  0.118365  0.093548  0.102973     0.331393  0.325645
# 8     90.0  0.119440  0.118838  0.098387  0.103163     0.339381  0.330603
# 9    100.0  0.120892  0.119207  0.100000  0.103175     0.344666  0.333061
# 11    10.0  0.083220  0.108345  0.070968  0.095693     0.217787  0.245713
# 12    20.0  0.097703  0.113946  0.082258  0.098414     0.262495  0.280575
# 13    30.0  0.101937  0.115209  0.079032  0.097777     0.276003  0.289232
# 14    40.0  0.107457  0.116571  0.082258  0.101639     0.297321  0.304516
# 15    50.0  0.111427  0.116987  0.091935  0.102860     0.319855  0.323420
# 16    60.0  0.113477  0.116978  0.090323  0.102721     0.321875  0.321143
# 17    70.0  0.117429  0.117881  0.091935  0.102860     0.337300  0.331819
# 18    80.0  0.119196  0.118173  0.096774  0.099948     0.342216  0.333034
# 19    90.0  0.120969  0.118404  0.096774  0.099948     0.349946  0.337168
# 20   100.0  0.121978  0.118568  0.100000  0.103175     0.351651  0.337108
# 22    10.0  0.067896  0.101695  0.066129  0.097457     0.181354  0.227263
# 23    20.0  0.080939  0.108596  0.082258  0.101639     0.206867  0.234694
# 24    30.0  0.090995  0.112213  0.075806  0.100299     0.229843  0.247841
# 25    40.0  0.097144  0.113922  0.074194  0.099896     0.243877  0.254729
# 26    50.0  0.101577  0.114656  0.079032  0.101022     0.259289  0.267212
# 27    60.0  0.104083  0.115253  0.077419  0.100674     0.267647  0.272695
# 28    70.0  0.105214  0.115464  0.080645  0.104478     0.277398  0.284178
# 29    80.0  0.107174  0.116147  0.082258  0.104764     0.283258  0.286678
# 19       0.249823   0.254314      1
# 20       0.245293   0.246238      1
# 22       0.174630   0.220851      2
# 23       0.199361   0.238374      2
# 24       0.209424   0.247809      2
# 25       0.209485   0.246088      2
# 26       0.214149   0.246449      2
# 27       0.212977   0.241798      2
# 28       0.214898   0.239878      2
# 29       0.224213   0.256095      2
# 30       0.223408   0.246616      2
# 31       0.233516   0.263025      2
# ..            ...        ...    ...
# 671      0.175275   0.234339     61
# 672      0.184223   0.243081     61
# 673      0.188221   0.237399     61
# 674      0.183553   0.221660     61
# 675      0.200208   0.233962     61
# 676      0.197128   0.220928     61
# 677      0.195757   0.215732     61
# 678      0.195861   0.216301     61
# 679      0.199858   0.224039     61
# 680      0.207071   0.233715     61
# 682      0.216539   0.249332     62
# 683      0.235008   0.261045     62
# 684      0.239031   0.263732     62
# 685      0.260459   0.295265     62
# 686      0.257978   0.287069     62
# 687      0.264192   0.287576     62
# 688      0.280062   0.308576     62
# 689      0.279246   0.306871     62
# 690      0.283171   0.307655     62
# 691      0.274654   0.300189     62
# 693      0.215258   0.250968     63
# 694      0.218568   0.251910     63
# 695      0.220938   0.254784     63
# 696      0.248496   0.281849     63
# 697      0.245358   0.272201     63
# 698      0.237108   0.251856     63
# 699      0.234863   0.247150     63
# 700      0.252661   0.262803     63
# 701      0.252730   0.253244     63
# 702      0.258239   0.255962     63
#
#                                               features
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# 5                                                 None
# 6                                                 None
# 7                                                 None
# 8                                                 None
# 9                                                 None
# 11                                    ('broadcaster',)
# 12                                    ('broadcaster',)
# 13                                    ('broadcaster',)
# 14                                    ('broadcaster',)
# 15                                    ('broadcaster',)
# 16                                    ('broadcaster',)
# 17                                    ('broadcaster',)
# 18                                    ('broadcaster',)
# 19                                    ('broadcaster',)
# 20                                    ('broadcaster',)
# 22                                        ('credits',)
# 23                                        ('credits',)
# 24                                        ('credits',)
# 25                                        ('credits',)
# 26                                        ('credits',)
# 27                                        ('credits',)
# 28                                        ('credits',)
# 29                                        ('credits',)
# 30                                        ('credits',)
# 31                                        ('credits',)
# ..                                                 ...
# 671  ('broadcaster', 'description_tfidf', 'genres',...
# 672  ('broadcaster', 'description_tfidf', 'genres',...
# 673  ('broadcaster', 'description_tfidf', 'genres',...
# 674  ('broadcaster', 'description_tfidf', 'genres',...
# 675  ('broadcaster', 'description_tfidf', 'genres',...
# 676  ('broadcaster', 'description_tfidf', 'genres',...
# 677  ('broadcaster', 'description_tfidf', 'genres',...
# 678  ('broadcaster', 'description_tfidf', 'genres',...
# 679  ('broadcaster', 'description_tfidf', 'genres',...
# 680  ('broadcaster', 'description_tfidf', 'genres',...
# 682  ('credits', 'description_tfidf', 'genres', 'ti...
# 683  ('credits', 'description_tfidf', 'genres', 'ti...
# 684  ('credits', 'description_tfidf', 'genres', 'ti...
# 685  ('credits', 'description_tfidf', 'genres', 'ti...
# 686  ('credits', 'description_tfidf', 'genres', 'ti...
# 687  ('credits', 'description_tfidf', 'genres', 'ti...
# 688  ('credits', 'description_tfidf', 'genres', 'ti...
# 689  ('credits', 'description_tfidf', 'genres', 'ti...
# 690  ('credits', 'description_tfidf', 'genres', 'ti...
# 691  ('credits', 'description_tfidf', 'genres', 'ti...
# 693  ('broadcaster', 'credits', 'description_tfidf'...
# 694  ('broadcaster', 'credits', 'description_tfidf'...
# 695  ('broadcaster', 'credits', 'description_tfidf'...
# 696  ('broadcaster', 'credits', 'description_tfidf'...
# 697  ('broadcaster', 'credits', 'description_tfidf'...
# 698  ('broadcaster', 'credits', 'description_tfidf'...
# 699  ('broadcaster', 'credits', 'description_tfidf'...
# 700  ('broadcaster', 'credits', 'description_tfidf'...
# 701  ('broadcaster', 'credits', 'description_tfidf'...
# 702  ('broadcaster', 'credits', 'description_tfidf'...
#
# [640 rows x 11 columns]

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))
ax = sns.lineplot(x="epoch", y="test_p5",data=df, hue='combi', ax=axes[0])
axes[0].set_title("Mean precision@5 for all content feature combinations")
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df, hue='combi', ax=axes[1])
axes[1].set_title("Mean reciprocal rank for all content feature combinations")
plt.show()

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))
ax = sns.lineplot(x="epoch", y="test_p52",data=df, hue='combi', ax=axes[0])
axes[0].set_title("Mean precision@5 for all content feature combinations")
ax = sns.lineplot(x="epoch", y="test_r-rank2",data=df, hue='combi', ax=axes[1])
axes[1].set_title("Mean reciprocal rank for all content feature combinations")
plt.show()

# %% [markdown]
# ### precision

# %%
df_p5.sort_values('test_p5', ascending=False)
# Out:
#      epoch   test_p5    p5_std  test_p52   p5_std2  test_r-rank  rank_std  \
# 559  100.0  0.127099  0.119079  0.103226  0.103125     0.369000  0.344924
# 394  100.0  0.125762  0.118976  0.090323  0.102721     0.365665  0.343925
# 97   100.0  0.125229  0.118484  0.098387  0.099987     0.364464  0.343068
# 592  100.0  0.125133  0.118592  0.087097  0.099164     0.362010  0.340808
# 328  100.0  0.125043  0.118578  0.091935  0.102860     0.364710  0.345263
# 361  100.0  0.124985  0.118069  0.090323  0.102721     0.365277  0.343638
# 427  100.0  0.124965  0.118692  0.104839  0.099883     0.359835  0.338588
# 449  100.0  0.124773  0.118559  0.101613  0.103163     0.357965  0.338008
# 372  100.0  0.124696  0.119083  0.104839  0.103062     0.364011  0.344189
# 482  100.0  0.124207  0.118578  0.090323  0.099531     0.357392  0.338517
# 493  100.0  0.123963  0.118378  0.098387  0.103163     0.360888  0.341991
# 339  100.0  0.123957  0.118607  0.103226  0.103125     0.361079  0.341864
# 570  100.0  0.123790  0.119009  0.090323  0.099531     0.357750  0.339860
# 603  100.0  0.123680  0.118728  0.106452  0.102973     0.358377  0.340259
# 504  100.0  0.123597  0.119025  0.101613  0.103163     0.352536  0.334307
# 405  100.0  0.123269  0.118939  0.098387  0.103163     0.354982  0.338049
# 691  100.0  0.123179  0.118187  0.095161  0.103062     0.359957  0.342052
# 383  100.0  0.123109  0.118732  0.087097  0.099164     0.353038  0.336509
# 438  100.0  0.122877  0.117701  0.085484  0.102149     0.352353  0.335170
# 614  100.0  0.122729  0.118144  0.090323  0.099531     0.353778  0.338098
# 460  100.0  0.122286  0.118250  0.090323  0.099531     0.356667  0.341550
# 20   100.0  0.121978  0.118568  0.100000  0.103175     0.351651  0.337108
# 130  100.0  0.121952  0.117964  0.088710  0.102556     0.354679  0.339062
# 273  100.0  0.121798  0.118525  0.090323  0.099531     0.346846  0.332195
# 9    100.0  0.120892  0.119207  0.100000  0.103175     0.344666  0.333061
# 702  100.0  0.120500  0.118171  0.095161  0.103062     0.339219  0.326173
# 108  100.0  0.120172  0.118997  0.098387  0.106244     0.338242  0.327204
# 691      0.274654   0.300189     62
# 383      0.266992   0.290412     34
# 438      0.245274   0.263962     39
# 614      0.272097   0.278523     55
# 460      0.309005   0.337352     41
# 20       0.245293   0.246238      1
# 130      0.246339   0.260873     11
# 273      0.262146   0.285197     24
# 9        0.263580   0.259976      0
# 702      0.258239   0.255962     63
# 108      0.271818   0.290712      9
# 581      0.276143   0.301107     52
# 350      0.245450   0.242240     31
# 471      0.232071   0.243759     42
# ..            ...        ...    ...
# 196      0.224996   0.247613     17
# 306      0.229148   0.252973     27
# 42       0.216229   0.237128      3
# 240      0.258696   0.279793     21
# 295      0.265782   0.293218     26
# 64       0.261483   0.288012      5
# 526      0.233253   0.271546     47
# 86       0.258195   0.285977      7
# 284      0.248580   0.275753     25
# 658      0.226471   0.248101     59
# 31       0.233516   0.263025      2
# 141      0.260573   0.297174     12
# 75       0.218576   0.237614      6
# 229      0.231226   0.255746     20
# 251      0.233128   0.268536     22
# 636      0.238844   0.271184     57
# 515      0.198839   0.213658     46
# 152      0.192520   0.214780     13
# 625      0.193576   0.226597     56
# 680      0.207071   0.233715     61
# 548      0.231154   0.256669     49
# 647      0.250023   0.283825     58
# 218      0.207588   0.237363     19
# 174      0.219416   0.247938     15
# 669      0.205095   0.228048     60
# 262      0.201346   0.237117     23
# 163      0.192637   0.221781     14
# 207      0.184769   0.206008     18
# 317      0.169615   0.194280     28
# 53       0.190933   0.237125      4
#
#                                               features
# 559  ('broadcaster', 'description_tfidf', 'title_tf...
# 394               ('credits', 'genres', 'title_tfidf')
# 97                ('broadcaster', 'description_tfidf')
# 592  ('credits', 'description_tfidf', 'genres', 'su...
# 328           ('broadcaster', 'genres', 'title_tfidf')
# 361         ('credits', 'description_tfidf', 'genres')
# 427     ('description_tfidf', 'genres', 'title_tfidf')
# 449  ('description_tfidf', 'title_tfidf', 'sub_tfidf')
# 372    ('credits', 'description_tfidf', 'title_tfidf')
# 482  ('broadcaster', 'credits', 'description_tfidf'...
# 493  ('broadcaster', 'credits', 'description_tfidf'...
# 339             ('broadcaster', 'genres', 'sub_tfidf')
# 570  ('broadcaster', 'genres', 'title_tfidf', 'sub_...
# 603  ('credits', 'description_tfidf', 'title_tfidf'...
# 504  ('broadcaster', 'credits', 'genres', 'title_tf...
# 405                 ('credits', 'genres', 'sub_tfidf')
# 691  ('credits', 'description_tfidf', 'genres', 'ti...
# 383      ('credits', 'description_tfidf', 'sub_tfidf')
# 438       ('description_tfidf', 'genres', 'sub_tfidf')
# 614  ('credits', 'genres', 'title_tfidf', 'sub_tfidf')
# 460             ('genres', 'title_tfidf', 'sub_tfidf')
# 20                                    ('broadcaster',)
# 130                       ('broadcaster', 'sub_tfidf')
# 273          ('broadcaster', 'credits', 'title_tfidf')
# 9                                                 None
# 702  ('broadcaster', 'credits', 'description_tfidf'...
# 108                          ('broadcaster', 'genres')
# 581  ('credits', 'description_tfidf', 'genres', 'ti...
# 350        ('broadcaster', 'title_tfidf', 'sub_tfidf')
# 471  ('broadcaster', 'credits', 'description_tfidf'...
# ..                                                 ...
# 196               ('description_tfidf', 'title_tfidf')
# 306  ('broadcaster', 'description_tfidf', 'title_tf...
# 42                              ('description_tfidf',)
# 240                       ('title_tfidf', 'sub_tfidf')
# 295     ('broadcaster', 'description_tfidf', 'genres')
# 64                                    ('title_tfidf',)
# 526  ('broadcaster', 'credits', 'title_tfidf', 'sub...
# 86                          ('broadcaster', 'credits')
# 284            ('broadcaster', 'credits', 'sub_tfidf')
# 658  ('broadcaster', 'credits', 'description_tfidf'...
# 31                                        ('credits',)
# 141                   ('credits', 'description_tfidf')
# 75                                      ('sub_tfidf',)
# 229                            ('genres', 'sub_tfidf')
# 251    ('broadcaster', 'credits', 'description_tfidf')
# 636  ('broadcaster', 'credits', 'description_tfidf'...
# 515  ('broadcaster', 'credits', 'genres', 'sub_tfidf')
# 152                              ('credits', 'genres')
# 625  ('description_tfidf', 'genres', 'title_tfidf',...
# 680  ('broadcaster', 'description_tfidf', 'genres',...
# 548  ('broadcaster', 'description_tfidf', 'genres',...
# 647  ('broadcaster', 'credits', 'description_tfidf'...
# 218                          ('genres', 'title_tfidf')
# 174                           ('credits', 'sub_tfidf')
# 669  ('broadcaster', 'credits', 'genres', 'title_tf...
# 262               ('broadcaster', 'credits', 'genres')
# 163                         ('credits', 'title_tfidf')
# 207                 ('description_tfidf', 'sub_tfidf')
# 317  ('broadcaster', 'description_tfidf', 'sub_tfidf')
# 53                                         ('genres',)
#
# [64 rows x 11 columns]

# %%
# highest mean p@k
p5 = df.groupby(['combi'])['test_p5'].transform(max) == df['test_p5']
df_p5 = df[p5].copy()
df_p5.sort_values('test_p5', ascending=False)
df_p5.loc[df_p5['test_p5'].idxmax()]
# Out:
# epoch                                                         100
# test_p5                                                  0.127099
# p5_std                                                   0.119079
# test_p52                                                 0.103226
# p5_std2                                                  0.103125
# test_r-rank                                                 0.369
# rank_std                                                 0.344924
# test_r-rank2                                             0.305334
# rank_std2                                                0.314717
# combi                                                          50
# features        ('broadcaster', 'description_tfidf', 'title_tf...
# Name: 559, dtype: object

# %%
high_base = [0, 50]
df_50 = df[df['combi'].isin(high_base)].copy()
f, axes = plt.subplots(1, 2, figsize=(16,3))
ax = sns.lineplot(x="epoch", y="test_p5",data=df_50, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[0])
axes[0].set_title("Mean precision@5 for baseline and top combination")
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df_50, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[1])
axes[1].set_title("Mean reciprocal rank for baseline and top combination")
plt.show()

# %%
# highest mean p@k
p52 = df.groupby(['combi'])['test_p52'].transform(max) == df['test_p52']
df_p52 = df[p52].copy()
df_p52.sort_values('test_p52', ascending=False)
df_p52.loc[df_p52['test_p52'].idxmax()]
# Out:
# epoch                                                          90
# test_p5                                                  0.122755
# p5_std                                                   0.118541
# test_p52                                                 0.108065
# p5_std2                                                   0.10286
# test_r-rank                                              0.353931
# rank_std                                                 0.337712
# test_r-rank2                                             0.307482
# rank_std2                                                0.316146
# combi                                                          54
# features        ('credits', 'description_tfidf', 'title_tfidf'...
# Name: 602, dtype: object

# %%
high_base = [0, 54]
df_54 = df[df['combi'].isin(high_base)].copy()
f, axes = plt.subplots(1, 2, figsize=(16,3))
ax = sns.lineplot(x="epoch", y="test_p52",data=df_54, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[0])
axes[0].set_title("Mean precision@5 for baseline and top combination")
ax = sns.lineplot(x="epoch", y="test_r-rank2",data=df_54, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[1])
axes[1].set_title("Mean reciprocal rank for baseline and top combination")
plt.show()

#
# 548      0.231154   0.256669     49
# 152      0.192520   0.214780     13
# 218      0.207588   0.237363     19
# 174      0.219416   0.247938     15
# 669      0.205095   0.228048     60
# 262      0.201346   0.237117     23
# 163      0.192637   0.221781     14
# 317      0.169615   0.194280     28
# 207      0.184769   0.206008     18
# 53       0.190933   0.237125      4
#
#                                               features
# 559  ('broadcaster', 'description_tfidf', 'title_tf...
# 394               ('credits', 'genres', 'title_tfidf')
# 361         ('credits', 'description_tfidf', 'genres')
# 328           ('broadcaster', 'genres', 'title_tfidf')
# 97                ('broadcaster', 'description_tfidf')
# 372    ('credits', 'description_tfidf', 'title_tfidf')
# 592  ('credits', 'description_tfidf', 'genres', 'su...
# 339             ('broadcaster', 'genres', 'sub_tfidf')
# 493  ('broadcaster', 'credits', 'description_tfidf'...
# 691  ('credits', 'description_tfidf', 'genres', 'ti...
# 427     ('description_tfidf', 'genres', 'title_tfidf')
# 603  ('credits', 'description_tfidf', 'title_tfidf'...
# 449  ('description_tfidf', 'title_tfidf', 'sub_tfidf')
# 570  ('broadcaster', 'genres', 'title_tfidf', 'sub_...
# 482  ('broadcaster', 'credits', 'description_tfidf'...
# 460             ('genres', 'title_tfidf', 'sub_tfidf')
# 405                 ('credits', 'genres', 'sub_tfidf')
# 130                       ('broadcaster', 'sub_tfidf')
# 614  ('credits', 'genres', 'title_tfidf', 'sub_tfidf')
# 383      ('credits', 'description_tfidf', 'sub_tfidf')
# 504  ('broadcaster', 'credits', 'genres', 'title_tf...
# 438       ('description_tfidf', 'genres', 'sub_tfidf')
# 20                                    ('broadcaster',)
# 273          ('broadcaster', 'credits', 'title_tfidf')
# 9                                                 None
# 350        ('broadcaster', 'title_tfidf', 'sub_tfidf')
# 581  ('credits', 'description_tfidf', 'genres', 'ti...
# 702  ('broadcaster', 'credits', 'description_tfidf'...
# 108                          ('broadcaster', 'genres')
# 185                    ('description_tfidf', 'genres')
# ..                                                 ...
# 240                       ('title_tfidf', 'sub_tfidf')
# 196               ('description_tfidf', 'title_tfidf')
# 42                              ('description_tfidf',)
# 526  ('broadcaster', 'credits', 'title_tfidf', 'sub...
# 537  ('broadcaster', 'description_tfidf', 'genres',...
# 64                                    ('title_tfidf',)
# 86                          ('broadcaster', 'credits')
# 306  ('broadcaster', 'description_tfidf', 'title_tf...
# 658  ('broadcaster', 'credits', 'description_tfidf'...
# 284            ('broadcaster', 'credits', 'sub_tfidf')
# 141                   ('credits', 'description_tfidf')
# 31                                        ('credits',)
# 229                            ('genres', 'sub_tfidf')
# 636  ('broadcaster', 'credits', 'description_tfidf'...
# 75                                      ('sub_tfidf',)
# 515  ('broadcaster', 'credits', 'genres', 'sub_tfidf')
# 251    ('broadcaster', 'credits', 'description_tfidf')
# 647  ('broadcaster', 'credits', 'description_tfidf'...
# 625  ('description_tfidf', 'genres', 'title_tfidf',...
# 680  ('broadcaster', 'description_tfidf', 'genres',...
# 548  ('broadcaster', 'description_tfidf', 'genres',...
# 152                              ('credits', 'genres')
# 218                          ('genres', 'title_tfidf')
# 174                           ('credits', 'sub_tfidf')
# 669  ('broadcaster', 'credits', 'genres', 'title_tf...
# 262               ('broadcaster', 'credits', 'genres')
# 163                         ('credits', 'title_tfidf')
# 317  ('broadcaster', 'description_tfidf', 'sub_tfidf')
# 207                 ('description_tfidf', 'sub_tfidf')
# 53                                         ('genres',)
#
# [64 rows x 11 columns]

# %%
# highest mean reciprocal rank
rr5 = df.groupby(['combi'])['test_r-rank'].transform(max) == df['test_r-rank']
df_rr5 = df[rr5].copy()
df_rr5.sort_values('test_r-rank', ascending=False)
df_rr5.loc[df_rr5['test_r-rank'].idxmax()]
# Out:
# epoch                                                         100
# test_p5                                                  0.127099
# p5_std                                                   0.119079
# test_p52                                                 0.103226
# p5_std2                                                  0.103125
# test_r-rank                                                 0.369
# rank_std                                                 0.344924
# test_r-rank2                                             0.305334
# rank_std2                                                0.314717
# combi                                                          50
# features        ('broadcaster', 'description_tfidf', 'title_tf...
# Name: 559, dtype: object

# %%
high_base = [0, 50]
df_50_rr = df[df['combi'].isin(high_base)].copy()
f, axes = plt.subplots(1, 2, figsize=(16,3))
ax = sns.lineplot(x="epoch", y="test_p5",data=df_50_rr, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[0])
axes[0].set_title("Mean precision@5 for baseline and top combination")
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df_50_rr, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[1])
axes[1].set_title("Mean reciprocal rank for baseline and top combination")
plt.show()

# %%
# highest mean reciprocal rank
rr52 = df.groupby(['combi'])['test_r-rank2'].transform(max) == df['test_r-rank2']
df_rr52 = df[rr52].copy()
df_rr52.sort_values('test_r-rank2', ascending=False)
df_rr52.loc[df_rr52['test_r-rank2'].idxmax()]
# Out:
# epoch                                               90
# test_p5                                       0.121239
# p5_std                                        0.118117
# test_p52                                     0.0919355
# p5_std2                                      0.0996743
# test_r-rank                                   0.352234
# rank_std                                       0.33974
# test_r-rank2                                  0.319817
# rank_std2                                     0.347753
# combi                                               41
# features        ('genres', 'title_tfidf', 'sub_tfidf')
# Name: 459, dtype: object

# %%
high_base = [0, 41]
df_41_rr = df[df['combi'].isin(high_base)].copy()
f, axes = plt.subplots(1, 2, figsize=(16,3))
ax = sns.lineplot(x="epoch", y="test_p52",data=df_41_rr, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[0])
axes[0].set_title("Mean precision@5 for baseline and top combination")
ax = sns.lineplot(x="epoch", y="test_r-rank2",data=df_41_rr, hue='combi', palette=sns.color_palette("Paired", 2), ax=axes[1])
axes[1].set_title("Mean reciprocal rank for baseline and top combination")
plt.show()

# %% [markdown]
# ## RQ3

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))
ax = sns.lineplot(x="epoch", y="test_p5",data=df, hue='combi', ax=axes[0])
axes[0].set_title("Mean p@5 for all content feature combinations")
axes[0].set(ylabel='mean p@5')
axes[0].axhline(0.008, ls='--')
axes[0].text(85, 0.005, "current p@5")
ax = sns.lineplot(x="epoch", y="test_r-rank",data=df, hue='combi', ax=axes[1])
axes[1].set_title("MRR for all content feature combinations")
axes[1].set(ylabel='MRR')
axes[1].axhline(0.024, ls='--')
axes[1].text(85, 0.015, "current mrr")
plt.show()

# %%
f, axes = plt.subplots(1, 2, figsize=(16,8))
ax = sns.lineplot(x="epoch", y="test_p52",data=df, hue='combi', ax=axes[0])
axes[0].set_title("Mean p@5 for all content feature combinations")
axes[0].set(ylabel='mean p@5')
axes[0].axhline(0.008, ls='--')
axes[0].text(85, 0.005, "current p@5")
ax = sns.lineplot(x="epoch", y="test_r-rank2",data=df, hue='combi', ax=axes[1])
axes[1].set_title("MRR for all content feature combinations")
axes[1].set(ylabel='MRR')
axes[1].axhline(0.024, ls='--')
axes[1].text(85, 0.015, "current mrr")
plt.show()
